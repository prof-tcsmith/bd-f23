# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo
import credentials

connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.xfd8951.mongodb.net/"
client = pymongo.MongoClient(connection_string)
db = client['cardio'] # this is a 'database'
collection = db['patients'] # this is a 'collection'

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [3], 'patient_info': {'fname': 'Tom', 'lname': 'Langston', 'mname': 'Jane'}, 'patient_numbers': ['491-469-5835', '197-572-7304'], 'weights': [382, 338, 176, 395, 90], 'height': 149, 'bp_readings': [{'Systolic': 104, 'Diastolic': 71, 'Rate': 101}, {'Systolic': 139, 'Diastolic': 72, 'Rate': 62}, {'Systolic': 116, 'Diastolic': 74, 'Rate': 65}, {'Systolic': 145, 'Diastolic': 96, 'Rate': 109}, {'Systolic': 138, 'Diastolic': 73, 'Rate': 89}, {'Systolic': 142, 'Diastolic': 72, 'Rate': 67}, {'Systolic': 127, 'Diastolic': 78, 'Rate': 68}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 65}, {'Systolic': 148, 'Diastolic': 79, 'Rate': 76}, {'Systolic': 103, 'Diastolic': 94, 'Rate': 60}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [6], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['415-760-5826', '167-629-4333'], 'weights': [114, 393, 90, 286, 375], 'height': 194, 'bp_readings': [{'Systolic': 120, 'Diastolic': 93, 'Rate': 102}, {'Systolic': 115, 'Diastolic': 77, 'Rate': 82}, {'Systolic': 143, 'Diastolic': 70, 'Rate': 65}, {'Systolic': 124, 'Diastolic': 93, 'Rate': 86}, {'Systolic': 115, 'Diastolic': 87, 'Rate': 86}, {'Systolic': 120, 'Diastolic': 79, 'Rate': 110}, {'Systolic': 138, 'Diastolic': 84, 'Rate': 83}]}
# {'_id': 3, 'office_num': [8], 'patient_info': {'fname': 'Betty', 'lname': 'Hart'}, 'patient_numbers': ['680-885-7023', '126-666-9983', '506-295-2581', '525-532-9530'], 'weights': [245, 363], 'height': 197, 'bp_readings': [{'Systolic': 134, 'Diastolic': 80, 'Rate': 69}, {'Systolic': 111, 'Diastolic': 87, 'Rate': 80}, {'Systolic': 135, 'Diastolic': 72, 'Rate': 73}]}
# {'_id': 4, 'office_num': [8], 'patient_info': {'fname': 'Liam', 'lname': 'Langston'}, 'patient_numbers': ['423-776-7934', '058-440-4795'], 'weights': [175, 154], 'height': 158, 'bp_readings': [{'Systolic': 138, 'Diastolic': 94, 'Rate': 97}, {'Systolic': 120, 'Diastolic': 90, 'Rate': 67}, {'Systolic': 125, 'Diastolic': 99, 'Rate': 86}, {'Systolic': 136, 'Diastolic': 79, 'Rate': 83}, {'Systolic': 120, 'Diastolic': 93, 'Rate': 80}, {'Systolic': 140, 'Diastolic': 96, 'Rate': 100}, {'Systolic': 131, 'Diastolic': 71, 'Rate': 75}, {'Systolic': 131, 'Diastolic': 89, 'Rate': 104}, {'Systolic': 137, 'Diastolic': 85, 'Rate': 61}, {'Systolic': 128, 'Diastolic': 97, 'Rate': 102}]}
# {'_id': 5, 'office_num': [1], 'patient_info': {'fname': 'Susan', 'lname': 'Hart'}, 'patient_numbers': ['510-596-0641', '510-462-8525', '924-495-6423', '579-460-9925'], 'weights': [297, 188, 353, 214], 'height': 168, 'bp_readings': [{'Systolic': 105, 'Diastolic': 72, 'Rate': 101}, {'Systolic': 126, 'Diastolic': 85, 'Rate': 77}, {'Systolic': 115, 'Diastolic': 95, 'Rate': 98}, {'Systolic': 130, 'Diastolic': 97, 'Rate': 89}, {'Systolic': 144, 'Diastolic': 86, 'Rate': 95}, {'Systolic': 121, 'Diastolic': 91, 'Rate': 78}, {'Systolic': 104, 'Diastolic': 70, 'Rate': 76}]}
# {'_id': 6, 'office_num': [8], 'patient_info': {'fname': 'July', 'lname': 'Boone'}, 'patient_numbers': ['085-109-9337', '438-390-3518'], 'weights': [383, 268, 344, 194], 'height': 122, 'bp_readings': [{'Systolic': 131, 'Diastolic': 80, 'Rate': 91}, {'Systolic': 143, 'Diastolic': 93, 'Rate': 107}, {'Systolic': 127, 'Diastolic': 92, 'Rate': 83}, {'Systolic': 139, 'Diastolic': 93, 'Rate': 93}, {'Systolic': 144, 'Diastolic': 70, 'Rate': 76}]}
# {'_id': 7, 'office_num': [1], 'patient_info': {'fname': 'John', 'lname': ' Fox'}, 'patient_numbers': ['522-702-4832', '069-610-1228', '723-103-9922', '256-750-7113'], 'weights': [111, 103], 'height': 107, 'bp_readings': [{'Systolic': 121, 'Diastolic': 73, 'Rate': 70}, {'Systolic': 125, 'Diastolic': 91, 'Rate': 101}, {'Systolic': 101, 'Diastolic': 86, 'Rate': 89}]}
# {'_id': 8, 'office_num': [10], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['328-020-1602', '184-530-1732'], 'weights': [195, 316], 'height': 107, 'bp_readings': [{'Systolic': 115, 'Diastolic': 71, 'Rate': 102}, {'Systolic': 132, 'Diastolic': 80, 'Rate': 83}, {'Systolic': 128, 'Diastolic': 97, 'Rate': 61}, {'Systolic': 126, 'Diastolic': 94, 'Rate': 65}]}
# {'_id': 9, 'office_num': [2], 'patient_info': {'fname': 'Richard', 'lname': 'Madden'}, 'patient_numbers': ['212-222-1165', '123-051-6108', '164-760-7365', '638-432-7011'], 'weights': [287, 140], 'height': 192, 'bp_readings': [{'Systolic': 136, 'Diastolic': 77, 'Rate': 90}, {'Systolic': 124, 'Diastolic': 77, 'Rate': 104}, {'Systolic': 124, 'Diastolic': 96, 'Rate': 77}, {'Systolic': 148, 'Diastolic': 93, 'Rate': 68}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 99}, {'Systolic': 103, 'Diastolic': 82, 'Rate': 75}]}
# {'_id': 10, 'office_num': [6], 'patient_info': {'fname': 'Jordan', 'lname': 'Hart'}, 'patient_numbers': ['350-189-2178', '557-500-6379'], 'weights': [120, 280, 122], 'height': 193, 'bp_readings': [{'Systolic': 115, 'Diastolic': 73, 'Rate': 62}, {'Systolic': 102, 'Diastolic': 92, 'Rate': 98}]}
# {'_id': 11, 'office_num': [5], 'patient_info': {'fname': 'James', 'lname': 'Granger'}, 'patient_numbers': ['970-655-5129', '856-126-0550', '230-973-2969'], 'weights': [299, 192], 'height': 180, 'bp_readings': [{'Systolic': 110, 'Diastolic': 84, 'Rate': 73}, {'Systolic': 145, 'Diastolic': 86, 'Rate': 70}, {'Systolic': 122, 'Diastolic': 89, 'Rate': 68}, {'Systolic': 141, 'Diastolic': 95, 'Rate': 73}]}
# {'_id': 12, 'office_num': [6], 'patient_info': {'fname': 'John', 'lname': 'Hart'}, 'patient_numbers': ['632-269-9832', '298-541-9138'], 'weights': [210, 183, 381, 228, 135], 'height': 176, 'bp_readings': [{'Systolic': 118, 'Diastolic': 72, 'Rate': 77}, {'Systolic': 102, 'Diastolic': 78, 'Rate': 61}, {'Systolic': 100, 'Diastolic': 70, 'Rate': 90}, {'Systolic': 122, 'Diastolic': 87, 'Rate': 66}, {'Systolic': 144, 'Diastolic': 90, 'Rate': 64}, {'Systolic': 150, 'Diastolic': 75, 'Rate': 85}]}
# {'_id': 13, 'office_num': [10], 'patient_info': {'fname': 'Jordan', 'lname': 'Madden'}, 'patient_numbers': ['327-637-1575', '250-574-2532'], 'weights': [344, 226], 'height': 166, 'bp_readings': [{'Systolic': 121, 'Diastolic': 75, 'Rate': 82}, {'Systolic': 141, 'Diastolic': 76, 'Rate': 93}, {'Systolic': 130, 'Diastolic': 81, 'Rate': 62}, {'Systolic': 141, 'Diastolic': 78, 'Rate': 61}, {'Systolic': 137, 'Diastolic': 75, 'Rate': 74}, {'Systolic': 114, 'Diastolic': 87, 'Rate': 90}, {'Systolic': 131, 'Diastolic': 95, 'Rate': 79}]}
# {'_id': 14, 'office_num': [5], 'patient_info': {'fname': 'Susan', 'lname': 'Carmichael'}, 'patient_numbers': ['469-630-5581', '555-412-6908', '189-563-7884', '941-950-6571'], 'weights': [296, 386, 269], 'height': 111, 'bp_readings': [{'Systolic': 132, 'Diastolic': 71, 'Rate': 72}, {'Systolic': 117, 'Diastolic': 86, 'Rate': 107}, {'Systolic': 143, 'Diastolic': 92, 'Rate': 105}]}
# {'_id': 15, 'office_num': [10], 'patient_info': {'fname': 'July', 'lname': 'Hart'}, 'patient_numbers': ['240-427-2849', '094-360-2909'], 'weights': [274, 390, 328, 182], 'height': 160, 'bp_readings': [{'Systolic': 112, 'Diastolic': 72, 'Rate': 76}, {'Systolic': 132, 'Diastolic': 85, 'Rate': 62}, {'Systolic': 126, 'Diastolic': 82, 'Rate': 85}, {'Systolic': 101, 'Diastolic': 81, 'Rate': 74}, {'Systolic': 143, 'Diastolic': 94, 'Rate': 76}, {'Systolic': 137, 'Diastolic': 83, 'Rate': 65}, {'Systolic': 107, 'Diastolic': 94, 'Rate': 108}, {'Systolic': 144, 'Diastolic': 91, 'Rate': 96}, {'Systolic': 131, 'Diastolic': 71, 'Rate': 74}, {'Systolic': 108, 'Diastolic': 88, 'Rate': 79}]}
# {'_id': 16, 'office_num': [6], 'patient_info': {'fname': 'James', 'lname': 'Hale'}, 'patient_numbers': ['804-283-0400', '620-629-5963'], 'weights': [391, 355, 236, 319], 'height': 114, 'bp_readings': [{'Systolic': 132, 'Diastolic': 81, 'Rate': 73}, {'Systolic': 103, 'Diastolic': 77, 'Rate': 85}, {'Systolic': 101, 'Diastolic': 88, 'Rate': 102}, {'Systolic': 124, 'Diastolic': 91, 'Rate': 60}]}
# {'_id': 17, 'office_num': [8], 'patient_info': {'fname': 'Jerry', 'lname': 'Granger'}, 'patient_numbers': ['581-137-7120', '282-897-4401', '905-168-7258', '231-626-4513'], 'weights': [135, 134, 116, 276], 'height': 125, 'bp_readings': [{'Systolic': 115, 'Diastolic': 96, 'Rate': 93}, {'Systolic': 133, 'Diastolic': 97, 'Rate': 101}, {'Systolic': 127, 'Diastolic': 89, 'Rate': 103}]}
# {'_id': 18, 'office_num': [7], 'patient_info': {'fname': 'Jordan', 'lname': ' Fox'}, 'patient_numbers': ['763-470-6078', '219-360-9648', '692-128-9528', '696-699-5536'], 'weights': [127, 155], 'height': 126, 'bp_readings': [{'Systolic': 125, 'Diastolic': 94, 'Rate': 98}, {'Systolic': 132, 'Diastolic': 77, 'Rate': 84}]}
# {'_id': 19, 'office_num': [8], 'patient_info': {'fname': 'Liam', 'lname': 'Madden'}, 'patient_numbers': ['036-801-9485', '610-660-5623', '673-971-0697', '852-010-1990'], 'weights': [297, 138], 'height': 121, 'bp_readings': [{'Systolic': 105, 'Diastolic': 84, 'Rate': 68}, {'Systolic': 122, 'Diastolic': 77, 'Rate': 69}, {'Systolic': 115, 'Diastolic': 71, 'Rate': 70}, {'Systolic': 104, 'Diastolic': 82, 'Rate': 88}, {'Systolic': 122, 'Diastolic': 70, 'Rate': 88}, {'Systolic': 133, 'Diastolic': 88, 'Rate': 92}]}
# {'_id': 20, 'office_num': [1], 'patient_info': {'fname': 'July', 'lname': 'Granger'}, 'patient_numbers': ['837-254-7720', '822-977-1201', '814-613-4426'], 'weights': [350, 111, 241, 350, 364], 'height': 106, 'bp_readings': [{'Systolic': 116, 'Diastolic': 95, 'Rate': 69}, {'Systolic': 117, 'Diastolic': 89, 'Rate': 60}, {'Systolic': 133, 'Diastolic': 98, 'Rate': 70}, {'Systolic': 124, 'Diastolic': 71, 'Rate': 73}, {'Systolic': 143, 'Diastolic': 74, 'Rate': 109}, {'Systolic': 119, 'Diastolic': 97, 'Rate': 76}]}
# {'_id': 21, 'office_num': [7], 'patient_info': {'fname': 'Ethan', 'lname': 'Madden'}, 'patient_numbers': ['782-633-3716', '678-242-4153', '554-920-0452'], 'weights': [185, 271], 'height': 124, 'bp_readings': [{'Systolic': 118, 'Diastolic': 80, 'Rate': 99}, {'Systolic': 141, 'Diastolic': 75, 'Rate': 66}, {'Systolic': 122, 'Diastolic': 89, 'Rate': 82}, {'Systolic': 100, 'Diastolic': 88, 'Rate': 73}, {'Systolic': 139, 'Diastolic': 86, 'Rate': 87}]}
# {'_id': 22, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Carmichael'}, 'patient_numbers': ['202-646-2306', '330-929-5788'], 'weights': [199, 159, 164, 106], 'height': 173, 'bp_readings': [{'Systolic': 129, 'Diastolic': 95, 'Rate': 70}, {'Systolic': 133, 'Diastolic': 70, 'Rate': 106}, {'Systolic': 127, 'Diastolic': 81, 'Rate': 104}]}
# {'_id': 23, 'office_num': [6], 'patient_info': {'fname': 'Jerry', 'lname': 'Smith'}, 'patient_numbers': ['404-184-6426', '311-461-3827', '128-976-6426'], 'weights': [139, 345], 'height': 178, 'bp_readings': [{'Systolic': 125, 'Diastolic': 98, 'Rate': 66}, {'Systolic': 110, 'Diastolic': 95, 'Rate': 63}]}
# {'_id': 24, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Smith'}, 'patient_numbers': ['325-259-6776', '330-715-2608'], 'weights': [335, 132], 'height': 151, 'bp_readings': [{'Systolic': 150, 'Diastolic': 98, 'Rate': 108}, {'Systolic': 138, 'Diastolic': 78, 'Rate': 106}]}
# {'_id': 25, 'office_num': [10], 'patient_info': {'fname': 'Jordan', 'lname': 'Boone'}, 'patient_numbers': ['245-001-8615', '352-948-4685'], 'weights': [291, 151], 'height': 148, 'bp_readings': [{'Systolic': 143, 'Diastolic': 88, 'Rate': 60}, {'Systolic': 121, 'Diastolic': 72, 'Rate': 62}]}
# {'_id': 26, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': ' Fox'}, 'patient_numbers': ['210-242-0818', '733-427-4083', '629-268-7822', '646-042-4033'], 'weights': [121, 167, 361, 277], 'height': 138, 'bp_readings': [{'Systolic': 139, 'Diastolic': 73, 'Rate': 75}, {'Systolic': 142, 'Diastolic': 80, 'Rate': 110}, {'Systolic': 122, 'Diastolic': 74, 'Rate': 87}, {'Systolic': 149, 'Diastolic': 93, 'Rate': 73}, {'Systolic': 108, 'Diastolic': 80, 'Rate': 61}]}
# {'_id': 27, 'office_num': [5], 'patient_info': {'fname': 'Jordan', 'lname': ' Fox'}, 'patient_numbers': ['862-300-9175', '271-569-5228', '741-232-0221'], 'weights': [167, 243, 255], 'height': 131, 'bp_readings': [{'Systolic': 116, 'Diastolic': 85, 'Rate': 100}, {'Systolic': 130, 'Diastolic': 76, 'Rate': 95}, {'Systolic': 129, 'Diastolic': 76, 'Rate': 110}, {'Systolic': 101, 'Diastolic': 94, 'Rate': 91}, {'Systolic': 121, 'Diastolic': 81, 'Rate': 99}, {'Systolic': 121, 'Diastolic': 93, 'Rate': 65}, {'Systolic': 102, 'Diastolic': 71, 'Rate': 97}, {'Systolic': 133, 'Diastolic': 88, 'Rate': 99}, {'Systolic': 102, 'Diastolic': 89, 'Rate': 76}, {'Systolic': 111, 'Diastolic': 75, 'Rate': 108}]}
# {'_id': 28, 'office_num': [3], 'patient_info': {'fname': 'Ethan', 'lname': 'Carmichael'}, 'patient_numbers': ['606-530-9932', '782-490-1320', '714-301-6123'], 'weights': [371, 172], 'height': 196, 'bp_readings': [{'Systolic': 133, 'Diastolic': 75, 'Rate': 64}, {'Systolic': 145, 'Diastolic': 76, 'Rate': 81}, {'Systolic': 123, 'Diastolic': 99, 'Rate': 93}, {'Systolic': 142, 'Diastolic': 84, 'Rate': 95}, {'Systolic': 129, 'Diastolic': 76, 'Rate': 101}]}
# {'_id': 29, 'office_num': [9], 'patient_info': {'fname': 'July', 'lname': 'Hart'}, 'patient_numbers': ['162-878-5614', '805-914-5641'], 'weights': [106, 103, 99, 365, 127], 'height': 130, 'bp_readings': [{'Systolic': 141, 'Diastolic': 80, 'Rate': 75}, {'Systolic': 133, 'Diastolic': 77, 'Rate': 85}, {'Systolic': 127, 'Diastolic': 98, 'Rate': 95}, {'Systolic': 124, 'Diastolic': 70, 'Rate': 94}, {'Systolic': 149, 'Diastolic': 94, 'Rate': 100}, {'Systolic': 115, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 108, 'Diastolic': 94, 'Rate': 60}]}
# {'_id': 30, 'office_num': [10], 'patient_info': {'fname': 'Richard', 'lname': 'Carmichael'}, 'patient_numbers': ['538-204-8083', '668-885-8958'], 'weights': [149, 394, 356, 325], 'height': 150, 'bp_readings': [{'Systolic': 104, 'Diastolic': 94, 'Rate': 64}, {'Systolic': 111, 'Diastolic': 90, 'Rate': 62}]}
# {'_id': 31, 'office_num': [5], 'patient_info': {'fname': 'Jerry', 'lname': ' Fox'}, 'patient_numbers': ['837-531-5350', '319-627-8283', '658-261-4870'], 'weights': [389, 279], 'height': 132, 'bp_readings': [{'Systolic': 114, 'Diastolic': 73, 'Rate': 88}, {'Systolic': 132, 'Diastolic': 90, 'Rate': 68}, {'Systolic': 143, 'Diastolic': 75, 'Rate': 60}, {'Systolic': 130, 'Diastolic': 90, 'Rate': 61}, {'Systolic': 122, 'Diastolic': 99, 'Rate': 87}]}
# {'_id': 32, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['154-270-0300', '757-927-6868'], 'weights': [259, 291], 'height': 169, 'bp_readings': [{'Systolic': 126, 'Diastolic': 89, 'Rate': 67}, {'Systolic': 113, 'Diastolic': 86, 'Rate': 78}, {'Systolic': 102, 'Diastolic': 86, 'Rate': 62}, {'Systolic': 133, 'Diastolic': 89, 'Rate': 110}, {'Systolic': 140, 'Diastolic': 79, 'Rate': 105}, {'Systolic': 139, 'Diastolic': 73, 'Rate': 74}, {'Systolic': 120, 'Diastolic': 94, 'Rate': 103}, {'Systolic': 149, 'Diastolic': 71, 'Rate': 105}, {'Systolic': 110, 'Diastolic': 71, 'Rate': 97}, {'Systolic': 109, 'Diastolic': 92, 'Rate': 80}]}
# {'_id': 33, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': ' Fox'}, 'patient_numbers': ['104-016-1889', '754-853-0068'], 'weights': [214, 306, 264, 235, 301], 'height': 103, 'bp_readings': [{'Systolic': 112, 'Diastolic': 78, 'Rate': 103}, {'Systolic': 127, 'Diastolic': 88, 'Rate': 62}]}
# {'_id': 34, 'office_num': [9], 'patient_info': {'fname': 'John', 'lname': 'Carmichael'}, 'patient_numbers': ['582-374-2019', '964-190-8066', '992-669-4642'], 'weights': [150, 174, 118, 382], 'height': 183, 'bp_readings': [{'Systolic': 103, 'Diastolic': 95, 'Rate': 101}, {'Systolic': 125, 'Diastolic': 97, 'Rate': 63}, {'Systolic': 148, 'Diastolic': 76, 'Rate': 73}, {'Systolic': 142, 'Diastolic': 90, 'Rate': 104}, {'Systolic': 146, 'Diastolic': 75, 'Rate': 103}, {'Systolic': 104, 'Diastolic': 92, 'Rate': 70}, {'Systolic': 150, 'Diastolic': 91, 'Rate': 76}]}
# {'_id': 35, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Madden'}, 'patient_numbers': ['459-810-9930', '475-071-5074'], 'weights': [354, 376, 263, 96], 'height': 124, 'bp_readings': [{'Systolic': 144, 'Diastolic': 70, 'Rate': 74}, {'Systolic': 117, 'Diastolic': 81, 'Rate': 87}, {'Systolic': 121, 'Diastolic': 82, 'Rate': 70}, {'Systolic': 115, 'Diastolic': 70, 'Rate': 96}, {'Systolic': 139, 'Diastolic': 92, 'Rate': 107}, {'Systolic': 150, 'Diastolic': 70, 'Rate': 101}, {'Systolic': 104, 'Diastolic': 98, 'Rate': 72}, {'Systolic': 119, 'Diastolic': 92, 'Rate': 62}, {'Systolic': 148, 'Diastolic': 89, 'Rate': 98}, {'Systolic': 131, 'Diastolic': 87, 'Rate': 73}]}
# {'_id': 36, 'office_num': [1], 'patient_info': {'fname': 'Betty', 'lname': 'Smith'}, 'patient_numbers': ['170-632-0191', '316-424-1495'], 'weights': [329, 123, 235, 280, 241], 'height': 197, 'bp_readings': [{'Systolic': 134, 'Diastolic': 86, 'Rate': 72}, {'Systolic': 118, 'Diastolic': 92, 'Rate': 82}, {'Systolic': 119, 'Diastolic': 84, 'Rate': 65}, {'Systolic': 145, 'Diastolic': 75, 'Rate': 98}, {'Systolic': 101, 'Diastolic': 99, 'Rate': 99}, {'Systolic': 100, 'Diastolic': 95, 'Rate': 109}, {'Systolic': 132, 'Diastolic': 87, 'Rate': 83}, {'Systolic': 148, 'Diastolic': 82, 'Rate': 88}, {'Systolic': 125, 'Diastolic': 93, 'Rate': 106}, {'Systolic': 119, 'Diastolic': 99, 'Rate': 93}]}
# {'_id': 37, 'office_num': [5], 'patient_info': {'fname': 'Richard', 'lname': 'Hale'}, 'patient_numbers': ['868-431-9726', '350-664-8399', '082-878-3717', '904-990-4312'], 'weights': [229, 280], 'height': 139, 'bp_readings': [{'Systolic': 150, 'Diastolic': 85, 'Rate': 110}, {'Systolic': 134, 'Diastolic': 85, 'Rate': 62}, {'Systolic': 135, 'Diastolic': 98, 'Rate': 109}, {'Systolic': 129, 'Diastolic': 78, 'Rate': 69}]}
# {'_id': 38, 'office_num': [7], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hart'}, 'patient_numbers': ['615-969-0905', '166-750-3024', '512-074-1777'], 'weights': [93, 345, 210], 'height': 164, 'bp_readings': [{'Systolic': 102, 'Diastolic': 82, 'Rate': 100}, {'Systolic': 101, 'Diastolic': 75, 'Rate': 69}, {'Systolic': 117, 'Diastolic': 78, 'Rate': 92}, {'Systolic': 150, 'Diastolic': 80, 'Rate': 109}, {'Systolic': 110, 'Diastolic': 71, 'Rate': 95}, {'Systolic': 122, 'Diastolic': 94, 'Rate': 102}, {'Systolic': 114, 'Diastolic': 72, 'Rate': 66}, {'Systolic': 105, 'Diastolic': 94, 'Rate': 85}]}
# {'_id': 39, 'office_num': [4], 'patient_info': {'fname': 'Betty', 'lname': 'Jones'}, 'patient_numbers': ['076-968-7531', '119-208-9196', '992-664-4826', '858-865-9396'], 'weights': [160, 355, 198], 'height': 193, 'bp_readings': [{'Systolic': 100, 'Diastolic': 84, 'Rate': 91}, {'Systolic': 112, 'Diastolic': 80, 'Rate': 95}, {'Systolic': 102, 'Diastolic': 77, 'Rate': 104}, {'Systolic': 120, 'Diastolic': 99, 'Rate': 68}, {'Systolic': 144, 'Diastolic': 85, 'Rate': 86}, {'Systolic': 101, 'Diastolic': 89, 'Rate': 74}, {'Systolic': 144, 'Diastolic': 90, 'Rate': 100}, {'Systolic': 111, 'Diastolic': 92, 'Rate': 96}]}
# {'_id': 40, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': 'Langston'}, 'patient_numbers': ['676-044-2457', '064-488-5083', '255-552-3113', '062-265-5007'], 'weights': [113, 356, 153, 133], 'height': 120, 'bp_readings': [{'Systolic': 131, 'Diastolic': 86, 'Rate': 92}, {'Systolic': 117, 'Diastolic': 98, 'Rate': 77}, {'Systolic': 104, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 136, 'Diastolic': 95, 'Rate': 88}, {'Systolic': 138, 'Diastolic': 85, 'Rate': 78}, {'Systolic': 108, 'Diastolic': 86, 'Rate': 94}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 102}, {'Systolic': 114, 'Diastolic': 88, 'Rate': 77}, {'Systolic': 122, 'Diastolic': 99, 'Rate': 99}, {'Systolic': 115, 'Diastolic': 93, 'Rate': 97}]}
# {'_id': 41, 'office_num': [7], 'patient_info': {'fname': 'Jerry', 'lname': 'Carmichael'}, 'patient_numbers': ['218-822-0246', '688-824-7094', '039-178-7626', '724-372-5816'], 'weights': [234, 318, 318], 'height': 155, 'bp_readings': [{'Systolic': 112, 'Diastolic': 99, 'Rate': 99}, {'Systolic': 117, 'Diastolic': 84, 'Rate': 92}]}
# {'_id': 42, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Boone'}, 'patient_numbers': ['928-214-3707', '850-077-2745'], 'weights': [267, 246, 276], 'height': 181, 'bp_readings': [{'Systolic': 132, 'Diastolic': 98, 'Rate': 104}, {'Systolic': 148, 'Diastolic': 89, 'Rate': 75}, {'Systolic': 110, 'Diastolic': 82, 'Rate': 76}, {'Systolic': 115, 'Diastolic': 88, 'Rate': 110}, {'Systolic': 121, 'Diastolic': 99, 'Rate': 61}]}
# {'_id': 43, 'office_num': [2], 'patient_info': {'fname': 'Ethan', 'lname': 'Granger'}, 'patient_numbers': ['183-425-2257', '806-074-0426', '786-016-4780'], 'weights': [325, 336], 'height': 131, 'bp_readings': [{'Systolic': 127, 'Diastolic': 86, 'Rate': 93}, {'Systolic': 107, 'Diastolic': 71, 'Rate': 91}, {'Systolic': 133, 'Diastolic': 73, 'Rate': 66}, {'Systolic': 117, 'Diastolic': 93, 'Rate': 104}, {'Systolic': 101, 'Diastolic': 76, 'Rate': 102}, {'Systolic': 136, 'Diastolic': 72, 'Rate': 107}, {'Systolic': 102, 'Diastolic': 74, 'Rate': 64}, {'Systolic': 123, 'Diastolic': 89, 'Rate': 91}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 74}]}
# {'_id': 44, 'office_num': [10], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['875-739-6018', '463-149-8871'], 'weights': [392, 341, 157, 306, 338], 'height': 113, 'bp_readings': [{'Systolic': 108, 'Diastolic': 98, 'Rate': 71}, {'Systolic': 115, 'Diastolic': 71, 'Rate': 65}, {'Systolic': 110, 'Diastolic': 97, 'Rate': 83}, {'Systolic': 107, 'Diastolic': 96, 'Rate': 107}, {'Systolic': 108, 'Diastolic': 90, 'Rate': 96}, {'Systolic': 136, 'Diastolic': 70, 'Rate': 104}, {'Systolic': 149, 'Diastolic': 91, 'Rate': 98}, {'Systolic': 137, 'Diastolic': 73, 'Rate': 62}]}
# {'_id': 45, 'office_num': [6], 'patient_info': {'fname': 'Jerry', 'lname': 'Hale'}, 'patient_numbers': ['930-567-8145', '591-789-1553'], 'weights': [136, 219, 262, 186, 320], 'height': 147, 'bp_readings': [{'Systolic': 141, 'Diastolic': 87, 'Rate': 92}, {'Systolic': 106, 'Diastolic': 84, 'Rate': 62}, {'Systolic': 124, 'Diastolic': 90, 'Rate': 87}, {'Systolic': 112, 'Diastolic': 92, 'Rate': 76}, {'Systolic': 133, 'Diastolic': 96, 'Rate': 106}, {'Systolic': 142, 'Diastolic': 99, 'Rate': 106}, {'Systolic': 105, 'Diastolic': 71, 'Rate': 65}]}
# {'_id': 46, 'office_num': [1], 'patient_info': {'fname': 'John', 'lname': 'Carmichael'}, 'patient_numbers': ['802-020-3293', '196-443-0632', '344-010-0188'], 'weights': [198, 321, 397, 346, 101], 'height': 136, 'bp_readings': [{'Systolic': 130, 'Diastolic': 90, 'Rate': 64}, {'Systolic': 123, 'Diastolic': 80, 'Rate': 90}]}
# {'_id': 47, 'office_num': [3], 'patient_info': {'fname': 'Ethan', 'lname': 'Granger'}, 'patient_numbers': ['666-057-7698', '046-900-9830', '273-920-5673', '526-740-5257'], 'weights': [196, 241, 166, 353, 163], 'height': 105, 'bp_readings': [{'Systolic': 130, 'Diastolic': 86, 'Rate': 94}, {'Systolic': 112, 'Diastolic': 91, 'Rate': 66}, {'Systolic': 113, 'Diastolic': 79, 'Rate': 90}, {'Systolic': 114, 'Diastolic': 71, 'Rate': 82}, {'Systolic': 129, 'Diastolic': 94, 'Rate': 109}]}
# {'_id': 48, 'office_num': [1], 'patient_info': {'fname': 'James', 'lname': 'Langston'}, 'patient_numbers': ['359-115-5448', '431-779-4169'], 'weights': [163, 244, 266], 'height': 112, 'bp_readings': [{'Systolic': 145, 'Diastolic': 73, 'Rate': 65}, {'Systolic': 121, 'Diastolic': 82, 'Rate': 103}, {'Systolic': 133, 'Diastolic': 80, 'Rate': 60}, {'Systolic': 126, 'Diastolic': 81, 'Rate': 94}, {'Systolic': 136, 'Diastolic': 82, 'Rate': 64}, {'Systolic': 124, 'Diastolic': 76, 'Rate': 93}, {'Systolic': 128, 'Diastolic': 97, 'Rate': 91}, {'Systolic': 107, 'Diastolic': 88, 'Rate': 109}, {'Systolic': 144, 'Diastolic': 91, 'Rate': 77}, {'Systolic': 109, 'Diastolic': 74, 'Rate': 60}]}
# {'_id': 49, 'office_num': [2], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['222-337-7752', '254-010-7927', '646-379-0769'], 'weights': [356, 207, 192, 107], 'height': 183, 'bp_readings': [{'Systolic': 103, 'Diastolic': 89, 'Rate': 72}, {'Systolic': 105, 'Diastolic': 80, 'Rate': 110}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^707'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %%
query = { "bp_readings": {"Systolic" : 104 , "Diastolic": 82, "Rate": 81}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 104}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 142} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "210-242-0818",
#         "733-427-4083",
#         "629-268-7822",
#         "646-042-4033"
#     ],
#     "weights": [
#         121,
#         167,
#         361,
#         277
#     ],
#     "height": 138,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 73,
#             "Rate": 75
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 80,
#             "Rate": 110
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 74,
#             "Rate": 87
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 93,
#             "Rate": 73
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 80,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "606-530-9932",
#         "782-490-1320",
#         "714-301-6123"
#     ],
#     "weights": [
#         371,
#         172
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 133,
#             "Diastolic": 75,
#             "Rate": 64
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 81
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 99,
#             "Rate": 93
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 84,
#             "Rate": 95
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 76,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "582-374-2019",
#         "964-190-8066",
#         "992-669-4642"
#     ],
#     "weights": [
#         150,
#         174,
#         118,
#         382
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 103,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 97,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 76,
#             "Rate": 73
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 104
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 75,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "930-567-8145",
#         "591-789-1553"
#     ],
#     "weights": [
#         136,
#         219,
#         262,
#         186,
#         320
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 87,
#             "Rate": 92
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 84,
#             "Rate": 62
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 92,
#             "Rate": 76
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 96,
#             "Rate": 106
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 99,
#             "Rate": 106
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 71,
#             "Rate": 65
#         }
#     ]
# }

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 2,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "415-760-5826",
#         "167-629-4333"
#     ],
#     "weights": [
#         114,
#         393,
#         90,
#         286,
#         375
#     ],
#     "height": 194,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 93,
#             "Rate": 102
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 77,
#             "Rate": 82
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 70,
#             "Rate": 65
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 93,
#             "Rate": 86
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 87,
#             "Rate": 86
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 79,
#             "Rate": 110
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 84,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 3,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "680-885-7023",
#         "126-666-9983",
#         "506-295-2581",
#         "525-532-9530"
#     ],
#     "weights": [
#         245,
#         363
#     ],
#     "height": 197,
#     "bp_readings": [
#         {
#             "Systolic": 134,
#             "Diastolic": 80,
#             "Rate": 69
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 87,
#             "Rate": 80
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 72,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 4,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "423-776-7934",
#         "058-440-4795"
#     ],
#     "weights": [
#         175,
#         154
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 97
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 90,
#             "Rate": 67
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 99,
#             "Rate": 86
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 79,
#             "Rate": 83
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 93,
#             "Rate": 80
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 96,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 75
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 89,
#             "Rate": 104
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 85,
#             "Rate": 61
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 97,
#             "Rate": 102
#         }
#     ]
# }
# {
#     "_id": 5,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "510-596-0641",
#         "510-462-8525",
#         "924-495-6423",
#         "579-460-9925"
#     ],
#     "weights": [
#         297,
#         188,
#         353,
#         214
#     ],
#     "height": 168,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 72,
#             "Rate": 101
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 85,
#             "Rate": 77
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 95,
#             "Rate": 98
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 97,
#             "Rate": 89
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 86,
#             "Rate": 95
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 91,
#             "Rate": 78
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 70,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "085-109-9337",
#         "438-390-3518"
#     ],
#     "weights": [
#         383,
#         268,
#         344,
#         194
#     ],
#     "height": 122,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 91
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 93,
#             "Rate": 107
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 92,
#             "Rate": 83
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 93,
#             "Rate": 93
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 70,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "328-020-1602",
#         "184-530-1732"
#     ],
#     "weights": [
#         195,
#         316
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 115,
#             "Diastolic": 71,
#             "Rate": 102
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 80,
#             "Rate": 83
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 97,
#             "Rate": 61
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 94,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "212-222-1165",
#         "123-051-6108",
#         "164-760-7365",
#         "638-432-7011"
#     ],
#     "weights": [
#         287,
#         140
#     ],
#     "height": 192,
#     "bp_readings": [
#         {
#             "Systolic": 136,
#             "Diastolic": 77,
#             "Rate": 90
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 77,
#             "Rate": 104
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 96,
#             "Rate": 77
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 93,
#             "Rate": 68
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 99
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 82,
#             "Rate": 75
#         }
#     ]
# }
# {
#     "_id": 11,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "970-655-5129",
#         "856-126-0550",
#         "230-973-2969"
#     ],
#     "weights": [
#         299,
#         192
#     ],
#     "height": 180,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 84,
#             "Rate": 73
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 86,
#             "Rate": 70
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 89,
#             "Rate": 68
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 95,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "632-269-9832",
#         "298-541-9138"
#     ],
#     "weights": [
#         210,
#         183,
#         381,
#         228,
#         135
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 118,
#             "Diastolic": 72,
#             "Rate": 77
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 78,
#             "Rate": 61
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 70,
#             "Rate": 90
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 87,
#             "Rate": 66
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 64
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 75,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "327-637-1575",
#         "250-574-2532"
#     ],
#     "weights": [
#         344,
#         226
#     ],
#     "height": 166,
#     "bp_readings": [
#         {
#             "Systolic": 121,
#             "Diastolic": 75,
#             "Rate": 82
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 76,
#             "Rate": 93
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 81,
#             "Rate": 62
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 78,
#             "Rate": 61
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 75,
#             "Rate": 74
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 87,
#             "Rate": 90
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 95,
#             "Rate": 79
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "469-630-5581",
#         "555-412-6908",
#         "189-563-7884",
#         "941-950-6571"
#     ],
#     "weights": [
#         296,
#         386,
#         269
#     ],
#     "height": 111,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 71,
#             "Rate": 72
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 86,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 92,
#             "Rate": 105
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "240-427-2849",
#         "094-360-2909"
#     ],
#     "weights": [
#         274,
#         390,
#         328,
#         182
#     ],
#     "height": 160,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 72,
#             "Rate": 76
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 85,
#             "Rate": 62
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 82,
#             "Rate": 85
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 94,
#             "Rate": 76
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 83,
#             "Rate": 65
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 94,
#             "Rate": 108
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 91,
#             "Rate": 96
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 74
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 88,
#             "Rate": 79
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "804-283-0400",
#         "620-629-5963"
#     ],
#     "weights": [
#         391,
#         355,
#         236,
#         319
#     ],
#     "height": 114,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 81,
#             "Rate": 73
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 77,
#             "Rate": 85
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 88,
#             "Rate": 102
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 91,
#             "Rate": 60
#         }
#     ]
# }
# {
#     "_id": 17,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "581-137-7120",
#         "282-897-4401",
#         "905-168-7258",
#         "231-626-4513"
#     ],
#     "weights": [
#         135,
#         134,
#         116,
#         276
#     ],
#     "height": 125,
#     "bp_readings": [
#         {
#             "Systolic": 115,
#             "Diastolic": 96,
#             "Rate": 93
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 97,
#             "Rate": 101
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 89,
#             "Rate": 103
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "763-470-6078",
#         "219-360-9648",
#         "692-128-9528",
#         "696-699-5536"
#     ],
#     "weights": [
#         127,
#         155
#     ],
#     "height": 126,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 94,
#             "Rate": 98
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 77,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 19,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "036-801-9485",
#         "610-660-5623",
#         "673-971-0697",
#         "852-010-1990"
#     ],
#     "weights": [
#         297,
#         138
#     ],
#     "height": 121,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 84,
#             "Rate": 68
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 71,
#             "Rate": 70
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 82,
#             "Rate": 88
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 70,
#             "Rate": 88
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 88,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 20,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "837-254-7720",
#         "822-977-1201",
#         "814-613-4426"
#     ],
#     "weights": [
#         350,
#         111,
#         241,
#         350,
#         364
#     ],
#     "height": 106,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 95,
#             "Rate": 69
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 89,
#             "Rate": 60
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 98,
#             "Rate": 70
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 71,
#             "Rate": 73
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 74,
#             "Rate": 109
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 97,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "782-633-3716",
#         "678-242-4153",
#         "554-920-0452"
#     ],
#     "weights": [
#         185,
#         271
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 118,
#             "Diastolic": 80,
#             "Rate": 99
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 75,
#             "Rate": 66
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 89,
#             "Rate": 82
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 88,
#             "Rate": 73
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 86,
#             "Rate": 87
#         }
#     ]
# }
# {
#     "_id": 22,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "202-646-2306",
#         "330-929-5788"
#     ],
#     "weights": [
#         199,
#         159,
#         164,
#         106
#     ],
#     "height": 173,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 95,
#             "Rate": 70
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 70,
#             "Rate": 106
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 81,
#             "Rate": 104
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "325-259-6776",
#         "330-715-2608"
#     ],
#     "weights": [
#         335,
#         132
#     ],
#     "height": 151,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 98,
#             "Rate": 108
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 78,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 25,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "245-001-8615",
#         "352-948-4685"
#     ],
#     "weights": [
#         291,
#         151
#     ],
#     "height": 148,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 88,
#             "Rate": 60
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 72,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "210-242-0818",
#         "733-427-4083",
#         "629-268-7822",
#         "646-042-4033"
#     ],
#     "weights": [
#         121,
#         167,
#         361,
#         277
#     ],
#     "height": 138,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 73,
#             "Rate": 75
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 80,
#             "Rate": 110
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 74,
#             "Rate": 87
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 93,
#             "Rate": 73
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 80,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "862-300-9175",
#         "271-569-5228",
#         "741-232-0221"
#     ],
#     "weights": [
#         167,
#         243,
#         255
#     ],
#     "height": 131,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 85,
#             "Rate": 100
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 76,
#             "Rate": 95
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 76,
#             "Rate": 110
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 94,
#             "Rate": 91
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 81,
#             "Rate": 99
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 93,
#             "Rate": 65
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 88,
#             "Rate": 99
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 89,
#             "Rate": 76
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 75,
#             "Rate": 108
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "606-530-9932",
#         "782-490-1320",
#         "714-301-6123"
#     ],
#     "weights": [
#         371,
#         172
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 133,
#             "Diastolic": 75,
#             "Rate": 64
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 81
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 99,
#             "Rate": 93
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 84,
#             "Rate": 95
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 76,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "162-878-5614",
#         "805-914-5641"
#     ],
#     "weights": [
#         106,
#         103,
#         99,
#         365,
#         127
#     ],
#     "height": 130,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 80,
#             "Rate": 75
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 77,
#             "Rate": 85
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 98,
#             "Rate": 95
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 70,
#             "Rate": 94
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 94,
#             "Rate": 100
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "837-531-5350",
#         "319-627-8283",
#         "658-261-4870"
#     ],
#     "weights": [
#         389,
#         279
#     ],
#     "height": 132,
#     "bp_readings": [
#         {
#             "Systolic": 114,
#             "Diastolic": 73,
#             "Rate": 88
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 90,
#             "Rate": 68
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 60
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 90,
#             "Rate": 61
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 99,
#             "Rate": 87
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "154-270-0300",
#         "757-927-6868"
#     ],
#     "weights": [
#         259,
#         291
#     ],
#     "height": 169,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 89,
#             "Rate": 67
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 86,
#             "Rate": 78
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 86,
#             "Rate": 62
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 89,
#             "Rate": 110
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 79,
#             "Rate": 105
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 73,
#             "Rate": 74
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 94,
#             "Rate": 103
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 71,
#             "Rate": 105
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 71,
#             "Rate": 97
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 92,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "582-374-2019",
#         "964-190-8066",
#         "992-669-4642"
#     ],
#     "weights": [
#         150,
#         174,
#         118,
#         382
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 103,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 97,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 76,
#             "Rate": 73
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 104
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 75,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "459-810-9930",
#         "475-071-5074"
#     ],
#     "weights": [
#         354,
#         376,
#         263,
#         96
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 70,
#             "Rate": 74
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 81,
#             "Rate": 87
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 82,
#             "Rate": 70
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 70,
#             "Rate": 96
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 92,
#             "Rate": 107
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 70,
#             "Rate": 101
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 92,
#             "Rate": 62
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 89,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "170-632-0191",
#         "316-424-1495"
#     ],
#     "weights": [
#         329,
#         123,
#         235,
#         280,
#         241
#     ],
#     "height": 197,
#     "bp_readings": [
#         {
#             "Systolic": 134,
#             "Diastolic": 86,
#             "Rate": 72
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 92,
#             "Rate": 82
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 84,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 75,
#             "Rate": 98
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 99,
#             "Rate": 99
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 95,
#             "Rate": 109
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 87,
#             "Rate": 83
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 82,
#             "Rate": 88
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 93,
#             "Rate": 106
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 99,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "868-431-9726",
#         "350-664-8399",
#         "082-878-3717",
#         "904-990-4312"
#     ],
#     "weights": [
#         229,
#         280
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 85,
#             "Rate": 110
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 85,
#             "Rate": 62
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 98,
#             "Rate": 109
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 78,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "615-969-0905",
#         "166-750-3024",
#         "512-074-1777"
#     ],
#     "weights": [
#         93,
#         345,
#         210
#     ],
#     "height": 164,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 75,
#             "Rate": 69
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 78,
#             "Rate": 92
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 109
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 71,
#             "Rate": 95
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 94,
#             "Rate": 102
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 72,
#             "Rate": 66
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 94,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "076-968-7531",
#         "119-208-9196",
#         "992-664-4826",
#         "858-865-9396"
#     ],
#     "weights": [
#         160,
#         355,
#         198
#     ],
#     "height": 193,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 84,
#             "Rate": 91
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 80,
#             "Rate": 95
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 77,
#             "Rate": 104
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 99,
#             "Rate": 68
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 85,
#             "Rate": 86
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 89,
#             "Rate": 74
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 100
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 92,
#             "Rate": 96
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "676-044-2457",
#         "064-488-5083",
#         "255-552-3113",
#         "062-265-5007"
#     ],
#     "weights": [
#         113,
#         356,
#         153,
#         133
#     ],
#     "height": 120,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 86,
#             "Rate": 92
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 98,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 95,
#             "Rate": 88
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 85,
#             "Rate": 78
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 86,
#             "Rate": 94
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 102
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 88,
#             "Rate": 77
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 99,
#             "Rate": 99
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 93,
#             "Rate": 97
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "928-214-3707",
#         "850-077-2745"
#     ],
#     "weights": [
#         267,
#         246,
#         276
#     ],
#     "height": 181,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 89,
#             "Rate": 75
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 82,
#             "Rate": 76
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 88,
#             "Rate": 110
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 99,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 43,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "183-425-2257",
#         "806-074-0426",
#         "786-016-4780"
#     ],
#     "weights": [
#         325,
#         336
#     ],
#     "height": 131,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 86,
#             "Rate": 93
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 71,
#             "Rate": 91
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 73,
#             "Rate": 66
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 104
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 76,
#             "Rate": 102
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 72,
#             "Rate": 107
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 74,
#             "Rate": 64
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 89,
#             "Rate": 91
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 74
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "875-739-6018",
#         "463-149-8871"
#     ],
#     "weights": [
#         392,
#         341,
#         157,
#         306,
#         338
#     ],
#     "height": 113,
#     "bp_readings": [
#         {
#             "Systolic": 108,
#             "Diastolic": 98,
#             "Rate": 71
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 71,
#             "Rate": 65
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 97,
#             "Rate": 83
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 96,
#             "Rate": 107
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 90,
#             "Rate": 96
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 70,
#             "Rate": 104
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 91,
#             "Rate": 98
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 73,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "930-567-8145",
#         "591-789-1553"
#     ],
#     "weights": [
#         136,
#         219,
#         262,
#         186,
#         320
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 87,
#             "Rate": 92
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 84,
#             "Rate": 62
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 92,
#             "Rate": 76
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 96,
#             "Rate": 106
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 99,
#             "Rate": 106
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 71,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 46,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "802-020-3293",
#         "196-443-0632",
#         "344-010-0188"
#     ],
#     "weights": [
#         198,
#         321,
#         397,
#         346,
#         101
#     ],
#     "height": 136,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 90,
#             "Rate": 64
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 80,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 47,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "666-057-7698",
#         "046-900-9830",
#         "273-920-5673",
#         "526-740-5257"
#     ],
#     "weights": [
#         196,
#         241,
#         166,
#         353,
#         163
#     ],
#     "height": 105,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 86,
#             "Rate": 94
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 91,
#             "Rate": 66
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 79,
#             "Rate": 90
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 71,
#             "Rate": 82
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 94,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 48,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "359-115-5448",
#         "431-779-4169"
#     ],
#     "weights": [
#         163,
#         244,
#         266
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 145,
#             "Diastolic": 73,
#             "Rate": 65
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 82,
#             "Rate": 103
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 80,
#             "Rate": 60
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 81,
#             "Rate": 94
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 82,
#             "Rate": 64
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 76,
#             "Rate": 93
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 97,
#             "Rate": 91
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 88,
#             "Rate": 109
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 91,
#             "Rate": 77
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 60
#         }
#     ]
# }

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Langston",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "491-469-5835",
#         "197-572-7304"
#     ],
#     "weights": [
#         382,
#         338,
#         176,
#         395,
#         90
#     ],
#     "height": 149,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 71,
#             "Rate": 101
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 62
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 73,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 78,
#             "Rate": 68
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 65
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 79,
#             "Rate": 76
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 94,
#             "Rate": 60
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 5,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "510-596-0641",
#         "510-462-8525",
#         "924-495-6423",
#         "579-460-9925"
#     ],
#     "weights": [
#         297,
#         188,
#         353,
#         214
#     ],
#     "height": 168,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 72,
#             "Rate": 101
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 85,
#             "Rate": 77
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 95,
#             "Rate": 98
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 97,
#             "Rate": 89
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 86,
#             "Rate": 95
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 91,
#             "Rate": 78
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 70,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 19,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "036-801-9485",
#         "610-660-5623",
#         "673-971-0697",
#         "852-010-1990"
#     ],
#     "weights": [
#         297,
#         138
#     ],
#     "height": 121,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 84,
#             "Rate": 68
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 71,
#             "Rate": 70
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 82,
#             "Rate": 88
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 70,
#             "Rate": 88
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 88,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "538-204-8083",
#         "668-885-8958"
#     ],
#     "weights": [
#         149,
#         394,
#         356,
#         325
#     ],
#     "height": 150,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 94,
#             "Rate": 64
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "582-374-2019",
#         "964-190-8066",
#         "992-669-4642"
#     ],
#     "weights": [
#         150,
#         174,
#         118,
#         382
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 103,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 97,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 76,
#             "Rate": 73
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 104
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 75,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "459-810-9930",
#         "475-071-5074"
#     ],
#     "weights": [
#         354,
#         376,
#         263,
#         96
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 70,
#             "Rate": 74
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 81,
#             "Rate": 87
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 82,
#             "Rate": 70
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 70,
#             "Rate": 96
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 92,
#             "Rate": 107
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 70,
#             "Rate": 101
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 92,
#             "Rate": 62
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 89,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "676-044-2457",
#         "064-488-5083",
#         "255-552-3113",
#         "062-265-5007"
#     ],
#     "weights": [
#         113,
#         356,
#         153,
#         133
#     ],
#     "height": 120,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 86,
#             "Rate": 92
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 98,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 95,
#             "Rate": 88
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 85,
#             "Rate": 78
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 86,
#             "Rate": 94
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 102
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 88,
#             "Rate": 77
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 99,
#             "Rate": 99
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 93,
#             "Rate": 97
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 12,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "632-269-9832",
#         "298-541-9138"
#     ],
#     "weights": [
#         210,
#         183,
#         381,
#         228,
#         135
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 118,
#             "Diastolic": 72,
#             "Rate": 77
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 78,
#             "Rate": 61
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 70,
#             "Rate": 90
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 87,
#             "Rate": 66
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 90,
#             "Rate": 64
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 75,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "325-259-6776",
#         "330-715-2608"
#     ],
#     "weights": [
#         335,
#         132
#     ],
#     "height": 151,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 98,
#             "Rate": 108
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 78,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "582-374-2019",
#         "964-190-8066",
#         "992-669-4642"
#     ],
#     "weights": [
#         150,
#         174,
#         118,
#         382
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 103,
#             "Diastolic": 95,
#             "Rate": 101
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 97,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 76,
#             "Rate": 73
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 104
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 75,
#             "Rate": 103
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "459-810-9930",
#         "475-071-5074"
#     ],
#     "weights": [
#         354,
#         376,
#         263,
#         96
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 70,
#             "Rate": 74
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 81,
#             "Rate": 87
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 82,
#             "Rate": 70
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 70,
#             "Rate": 96
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 92,
#             "Rate": 107
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 70,
#             "Rate": 101
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 72
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 92,
#             "Rate": 62
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 89,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "868-431-9726",
#         "350-664-8399",
#         "082-878-3717",
#         "904-990-4312"
#     ],
#     "weights": [
#         229,
#         280
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 85,
#             "Rate": 110
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 85,
#             "Rate": 62
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 98,
#             "Rate": 109
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 78,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "615-969-0905",
#         "166-750-3024",
#         "512-074-1777"
#     ],
#     "weights": [
#         93,
#         345,
#         210
#     ],
#     "height": 164,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 75,
#             "Rate": 69
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 78,
#             "Rate": 92
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 80,
#             "Rate": 109
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 71,
#             "Rate": 95
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 94,
#             "Rate": 102
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 72,
#             "Rate": 66
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 94,
#             "Rate": 85
#         }
#     ]
# }

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
