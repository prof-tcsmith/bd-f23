# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo
import credentials

connection_string = f"mongodb+srv://{credentials.username}:{credentials.password}@cluster0.djnup4f.mongodb.net/"
client = pymongo.MongoClient(connection_string)
db = client['cardio'] # this is a 'database'
collection = db['patients'] # this is a 'collection'

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [5], 'patient_info': {'fname': 'Susan', 'lname': 'Madden', 'mname': 'Jane'}, 'patient_numbers': ['428-197-6514', '682-094-9620', '642-487-2807'], 'weights': [114], 'height': 107, 'bp_readings': [{'Systolic': 116, 'Diastolic': 85, 'Rate': 108}, {'Systolic': 129, 'Diastolic': 98, 'Rate': 107}, {'Systolic': 143, 'Diastolic': 82, 'Rate': 62}, {'Systolic': 114, 'Diastolic': 93, 'Rate': 70}, {'Systolic': 141, 'Diastolic': 73, 'Rate': 99}, {'Systolic': 111, 'Diastolic': 90, 'Rate': 87}, {'Systolic': 114, 'Diastolic': 82, 'Rate': 72}, {'Systolic': 146, 'Diastolic': 97, 'Rate': 82}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [5], 'patient_info': {'fname': 'Jordan', 'lname': 'Madden'}, 'patient_numbers': ['330-584-3338', '415-375-0832'], 'weights': [328, 295, 352, 351, 332], 'height': 190, 'bp_readings': [{'Systolic': 147, 'Diastolic': 94, 'Rate': 109}, {'Systolic': 138, 'Diastolic': 88, 'Rate': 75}, {'Systolic': 120, 'Diastolic': 94, 'Rate': 86}, {'Systolic': 127, 'Diastolic': 99, 'Rate': 78}, {'Systolic': 135, 'Diastolic': 77, 'Rate': 104}, {'Systolic': 138, 'Diastolic': 75, 'Rate': 83}, {'Systolic': 100, 'Diastolic': 98, 'Rate': 91}, {'Systolic': 147, 'Diastolic': 70, 'Rate': 100}, {'Systolic': 130, 'Diastolic': 90, 'Rate': 110}, {'Systolic': 127, 'Diastolic': 79, 'Rate': 63}]}
# {'_id': 3, 'office_num': [3], 'patient_info': {'fname': 'James', 'lname': 'Smith'}, 'patient_numbers': ['026-379-7912', '724-783-2689', '853-048-8627', '223-949-1900'], 'weights': [225], 'height': 185, 'bp_readings': [{'Systolic': 150, 'Diastolic': 90, 'Rate': 101}, {'Systolic': 149, 'Diastolic': 87, 'Rate': 65}]}
# {'_id': 4, 'office_num': [6], 'patient_info': {'fname': 'Ethan', 'lname': 'Jones'}, 'patient_numbers': ['325-874-0334', '844-258-5821'], 'weights': [375, 180, 234, 318, 244], 'height': 181, 'bp_readings': [{'Systolic': 111, 'Diastolic': 93, 'Rate': 67}, {'Systolic': 106, 'Diastolic': 70, 'Rate': 105}, {'Systolic': 107, 'Diastolic': 84, 'Rate': 107}, {'Systolic': 136, 'Diastolic': 85, 'Rate': 66}, {'Systolic': 128, 'Diastolic': 84, 'Rate': 75}, {'Systolic': 125, 'Diastolic': 73, 'Rate': 93}, {'Systolic': 131, 'Diastolic': 78, 'Rate': 103}, {'Systolic': 146, 'Diastolic': 95, 'Rate': 110}, {'Systolic': 119, 'Diastolic': 98, 'Rate': 75}, {'Systolic': 139, 'Diastolic': 71, 'Rate': 107}]}
# {'_id': 5, 'office_num': [4], 'patient_info': {'fname': 'Jordan', 'lname': 'Boone'}, 'patient_numbers': ['832-070-2125', '671-020-4408'], 'weights': [98], 'height': 100, 'bp_readings': [{'Systolic': 117, 'Diastolic': 77, 'Rate': 90}, {'Systolic': 133, 'Diastolic': 71, 'Rate': 87}, {'Systolic': 147, 'Diastolic': 88, 'Rate': 98}, {'Systolic': 103, 'Diastolic': 73, 'Rate': 86}, {'Systolic': 136, 'Diastolic': 85, 'Rate': 66}, {'Systolic': 145, 'Diastolic': 78, 'Rate': 100}, {'Systolic': 131, 'Diastolic': 91, 'Rate': 96}, {'Systolic': 132, 'Diastolic': 92, 'Rate': 70}, {'Systolic': 125, 'Diastolic': 74, 'Rate': 88}]}
# {'_id': 6, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['905-970-6550', '772-875-1518', '398-548-6975', '515-125-6338'], 'weights': [135, 337, 290, 172], 'height': 158, 'bp_readings': [{'Systolic': 117, 'Diastolic': 78, 'Rate': 98}, {'Systolic': 134, 'Diastolic': 99, 'Rate': 73}, {'Systolic': 150, 'Diastolic': 92, 'Rate': 68}, {'Systolic': 109, 'Diastolic': 93, 'Rate': 61}, {'Systolic': 105, 'Diastolic': 88, 'Rate': 86}, {'Systolic': 146, 'Diastolic': 83, 'Rate': 78}]}
# {'_id': 7, 'office_num': [9], 'patient_info': {'fname': 'John', 'lname': ' Fox'}, 'patient_numbers': ['812-766-1297', '491-650-1592', '109-200-6643', '660-432-9141'], 'weights': [160], 'height': 133, 'bp_readings': [{'Systolic': 140, 'Diastolic': 91, 'Rate': 82}, {'Systolic': 111, 'Diastolic': 81, 'Rate': 91}, {'Systolic': 129, 'Diastolic': 84, 'Rate': 79}, {'Systolic': 104, 'Diastolic': 95, 'Rate': 102}, {'Systolic': 142, 'Diastolic': 82, 'Rate': 76}, {'Systolic': 123, 'Diastolic': 88, 'Rate': 82}, {'Systolic': 106, 'Diastolic': 77, 'Rate': 69}, {'Systolic': 124, 'Diastolic': 97, 'Rate': 61}]}
# {'_id': 8, 'office_num': [5], 'patient_info': {'fname': 'John', 'lname': 'Jones'}, 'patient_numbers': ['102-359-7615', '953-103-2060'], 'weights': [369, 94, 146, 319], 'height': 178, 'bp_readings': [{'Systolic': 120, 'Diastolic': 85, 'Rate': 96}, {'Systolic': 101, 'Diastolic': 79, 'Rate': 62}, {'Systolic': 128, 'Diastolic': 91, 'Rate': 82}, {'Systolic': 131, 'Diastolic': 71, 'Rate': 60}, {'Systolic': 147, 'Diastolic': 73, 'Rate': 84}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 80}]}
# {'_id': 9, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Carmichael'}, 'patient_numbers': ['983-839-0125', '513-601-3255', '498-830-7389', '742-807-3647'], 'weights': [364, 296, 244], 'height': 165, 'bp_readings': [{'Systolic': 149, 'Diastolic': 99, 'Rate': 75}, {'Systolic': 136, 'Diastolic': 91, 'Rate': 80}, {'Systolic': 125, 'Diastolic': 94, 'Rate': 68}, {'Systolic': 148, 'Diastolic': 71, 'Rate': 62}, {'Systolic': 108, 'Diastolic': 99, 'Rate': 66}, {'Systolic': 149, 'Diastolic': 91, 'Rate': 103}, {'Systolic': 126, 'Diastolic': 74, 'Rate': 77}]}
# {'_id': 10, 'office_num': [9], 'patient_info': {'fname': 'Tom', 'lname': 'Granger'}, 'patient_numbers': ['845-379-8843', '029-833-8590', '289-985-9290'], 'weights': [150, 117, 323], 'height': 188, 'bp_readings': [{'Systolic': 102, 'Diastolic': 98, 'Rate': 88}, {'Systolic': 110, 'Diastolic': 97, 'Rate': 94}, {'Systolic': 138, 'Diastolic': 80, 'Rate': 62}, {'Systolic': 124, 'Diastolic': 85, 'Rate': 81}, {'Systolic': 146, 'Diastolic': 82, 'Rate': 99}, {'Systolic': 149, 'Diastolic': 82, 'Rate': 100}, {'Systolic': 102, 'Diastolic': 81, 'Rate': 60}]}
# {'_id': 11, 'office_num': [2], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['257-519-5978', '310-512-3322', '075-967-8363', '312-232-3687'], 'weights': [358, 286, 345, 225], 'height': 111, 'bp_readings': [{'Systolic': 118, 'Diastolic': 73, 'Rate': 77}, {'Systolic': 137, 'Diastolic': 92, 'Rate': 84}, {'Systolic': 129, 'Diastolic': 97, 'Rate': 67}, {'Systolic': 109, 'Diastolic': 90, 'Rate': 90}, {'Systolic': 110, 'Diastolic': 84, 'Rate': 63}, {'Systolic': 146, 'Diastolic': 83, 'Rate': 110}, {'Systolic': 133, 'Diastolic': 86, 'Rate': 63}, {'Systolic': 121, 'Diastolic': 98, 'Rate': 108}, {'Systolic': 132, 'Diastolic': 70, 'Rate': 78}]}
# {'_id': 12, 'office_num': [3], 'patient_info': {'fname': 'Ethan', 'lname': ' Fox'}, 'patient_numbers': ['166-119-7349', '459-618-2479', '742-755-6140', '259-737-1478'], 'weights': [374, 272, 204, 275], 'height': 112, 'bp_readings': [{'Systolic': 104, 'Diastolic': 95, 'Rate': 67}, {'Systolic': 149, 'Diastolic': 72, 'Rate': 83}]}
# {'_id': 13, 'office_num': [8], 'patient_info': {'fname': 'Ethan', 'lname': 'Boone'}, 'patient_numbers': ['470-215-7864', '993-649-9534'], 'weights': [277, 189, 202], 'height': 198, 'bp_readings': [{'Systolic': 120, 'Diastolic': 95, 'Rate': 63}, {'Systolic': 116, 'Diastolic': 90, 'Rate': 72}, {'Systolic': 113, 'Diastolic': 84, 'Rate': 77}, {'Systolic': 136, 'Diastolic': 93, 'Rate': 104}, {'Systolic': 119, 'Diastolic': 87, 'Rate': 88}, {'Systolic': 121, 'Diastolic': 86, 'Rate': 99}, {'Systolic': 124, 'Diastolic': 76, 'Rate': 99}]}
# {'_id': 14, 'office_num': [3], 'patient_info': {'fname': 'Jerry', 'lname': 'Hale'}, 'patient_numbers': ['737-198-8430', '980-236-4727', '910-643-9695', '140-238-4980'], 'weights': [163], 'height': 157, 'bp_readings': [{'Systolic': 145, 'Diastolic': 90, 'Rate': 91}, {'Systolic': 117, 'Diastolic': 74, 'Rate': 76}, {'Systolic': 137, 'Diastolic': 84, 'Rate': 110}, {'Systolic': 147, 'Diastolic': 88, 'Rate': 80}, {'Systolic': 138, 'Diastolic': 87, 'Rate': 98}, {'Systolic': 134, 'Diastolic': 92, 'Rate': 92}]}
# {'_id': 15, 'office_num': [8], 'patient_info': {'fname': 'Susan', 'lname': 'Smith'}, 'patient_numbers': ['419-192-6354', '536-047-6128', '854-304-0720', '745-795-1956'], 'weights': [334, 147, 300, 265], 'height': 200, 'bp_readings': [{'Systolic': 144, 'Diastolic': 99, 'Rate': 91}, {'Systolic': 121, 'Diastolic': 93, 'Rate': 89}, {'Systolic': 145, 'Diastolic': 75, 'Rate': 73}, {'Systolic': 124, 'Diastolic': 74, 'Rate': 105}, {'Systolic': 129, 'Diastolic': 79, 'Rate': 96}, {'Systolic': 140, 'Diastolic': 86, 'Rate': 85}, {'Systolic': 111, 'Diastolic': 83, 'Rate': 96}, {'Systolic': 121, 'Diastolic': 88, 'Rate': 101}, {'Systolic': 135, 'Diastolic': 73, 'Rate': 69}]}
# {'_id': 16, 'office_num': [6], 'patient_info': {'fname': 'Liam', 'lname': 'Carmichael'}, 'patient_numbers': ['987-090-9857', '141-196-9110', '190-909-3585', '565-915-2229'], 'weights': [310, 361, 275], 'height': 103, 'bp_readings': [{'Systolic': 113, 'Diastolic': 88, 'Rate': 99}, {'Systolic': 138, 'Diastolic': 94, 'Rate': 64}, {'Systolic': 142, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 121, 'Diastolic': 79, 'Rate': 63}, {'Systolic': 148, 'Diastolic': 97, 'Rate': 87}]}
# {'_id': 17, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': 'Jones'}, 'patient_numbers': ['782-348-8742', '188-304-9286', '675-225-8938', '389-246-5387'], 'weights': [110, 117, 353, 98, 200], 'height': 185, 'bp_readings': [{'Systolic': 132, 'Diastolic': 84, 'Rate': 93}, {'Systolic': 141, 'Diastolic': 75, 'Rate': 100}]}
# {'_id': 18, 'office_num': [6], 'patient_info': {'fname': 'Liam', 'lname': 'Langston'}, 'patient_numbers': ['056-124-1055', '856-505-3190'], 'weights': [326, 392, 390, 244], 'height': 101, 'bp_readings': [{'Systolic': 141, 'Diastolic': 95, 'Rate': 62}, {'Systolic': 104, 'Diastolic': 98, 'Rate': 109}, {'Systolic': 119, 'Diastolic': 95, 'Rate': 88}, {'Systolic': 127, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 109, 'Diastolic': 74, 'Rate': 107}, {'Systolic': 145, 'Diastolic': 76, 'Rate': 60}, {'Systolic': 141, 'Diastolic': 77, 'Rate': 81}, {'Systolic': 150, 'Diastolic': 96, 'Rate': 95}, {'Systolic': 148, 'Diastolic': 82, 'Rate': 75}, {'Systolic': 136, 'Diastolic': 82, 'Rate': 69}]}
# {'_id': 19, 'office_num': [5], 'patient_info': {'fname': 'Tom', 'lname': 'Granger'}, 'patient_numbers': ['268-048-3400', '144-240-2897'], 'weights': [104, 391, 286, 381], 'height': 111, 'bp_readings': [{'Systolic': 113, 'Diastolic': 84, 'Rate': 64}, {'Systolic': 106, 'Diastolic': 71, 'Rate': 98}, {'Systolic': 128, 'Diastolic': 96, 'Rate': 92}]}
# {'_id': 20, 'office_num': [3], 'patient_info': {'fname': 'James', 'lname': 'Madden'}, 'patient_numbers': ['116-087-7438', '108-723-9743', '330-487-2243', '746-830-0925'], 'weights': [246, 269, 161], 'height': 115, 'bp_readings': [{'Systolic': 133, 'Diastolic': 77, 'Rate': 85}, {'Systolic': 109, 'Diastolic': 82, 'Rate': 86}, {'Systolic': 136, 'Diastolic': 97, 'Rate': 78}, {'Systolic': 117, 'Diastolic': 99, 'Rate': 72}, {'Systolic': 107, 'Diastolic': 96, 'Rate': 84}]}
# {'_id': 21, 'office_num': [5], 'patient_info': {'fname': 'Richard', 'lname': ' Fox'}, 'patient_numbers': ['851-769-5203', '088-464-0425'], 'weights': [267, 123, 96, 335], 'height': 143, 'bp_readings': [{'Systolic': 132, 'Diastolic': 98, 'Rate': 104}, {'Systolic': 134, 'Diastolic': 81, 'Rate': 82}]}
# {'_id': 22, 'office_num': [2], 'patient_info': {'fname': 'Liam', 'lname': 'Jones'}, 'patient_numbers': ['587-513-2813', '816-540-7992'], 'weights': [312, 227, 320, 281], 'height': 179, 'bp_readings': [{'Systolic': 123, 'Diastolic': 92, 'Rate': 77}, {'Systolic': 101, 'Diastolic': 76, 'Rate': 77}, {'Systolic': 101, 'Diastolic': 95, 'Rate': 107}, {'Systolic': 113, 'Diastolic': 89, 'Rate': 107}, {'Systolic': 106, 'Diastolic': 83, 'Rate': 70}, {'Systolic': 127, 'Diastolic': 71, 'Rate': 94}, {'Systolic': 106, 'Diastolic': 86, 'Rate': 100}]}
# {'_id': 23, 'office_num': [1], 'patient_info': {'fname': 'Liam', 'lname': 'Langston'}, 'patient_numbers': ['369-446-8443', '410-304-7750', '825-486-9958', '524-016-6964'], 'weights': [324, 307], 'height': 106, 'bp_readings': [{'Systolic': 112, 'Diastolic': 82, 'Rate': 68}, {'Systolic': 148, 'Diastolic': 93, 'Rate': 64}, {'Systolic': 132, 'Diastolic': 78, 'Rate': 95}, {'Systolic': 127, 'Diastolic': 83, 'Rate': 108}, {'Systolic': 140, 'Diastolic': 94, 'Rate': 73}, {'Systolic': 119, 'Diastolic': 86, 'Rate': 107}, {'Systolic': 142, 'Diastolic': 87, 'Rate': 76}, {'Systolic': 111, 'Diastolic': 81, 'Rate': 66}, {'Systolic': 112, 'Diastolic': 77, 'Rate': 74}]}
# {'_id': 24, 'office_num': [1], 'patient_info': {'fname': 'July', 'lname': 'Granger'}, 'patient_numbers': ['667-099-5859', '108-001-9079', '381-089-1766'], 'weights': [391, 264, 120, 282], 'height': 123, 'bp_readings': [{'Systolic': 149, 'Diastolic': 96, 'Rate': 83}, {'Systolic': 101, 'Diastolic': 73, 'Rate': 64}, {'Systolic': 103, 'Diastolic': 98, 'Rate': 63}, {'Systolic': 142, 'Diastolic': 78, 'Rate': 78}, {'Systolic': 142, 'Diastolic': 90, 'Rate': 73}, {'Systolic': 130, 'Diastolic': 77, 'Rate': 70}]}
# {'_id': 25, 'office_num': [9], 'patient_info': {'fname': 'Jordan', 'lname': 'Hart'}, 'patient_numbers': ['855-210-0926', '180-863-6751', '070-413-8714', '865-042-9651'], 'weights': [223, 348], 'height': 104, 'bp_readings': [{'Systolic': 130, 'Diastolic': 86, 'Rate': 96}, {'Systolic': 143, 'Diastolic': 77, 'Rate': 95}]}
# {'_id': 26, 'office_num': [9], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hart'}, 'patient_numbers': ['864-973-0653', '167-621-3278', '638-223-2052'], 'weights': [160, 280, 142, 140], 'height': 173, 'bp_readings': [{'Systolic': 106, 'Diastolic': 86, 'Rate': 68}, {'Systolic': 116, 'Diastolic': 95, 'Rate': 63}, {'Systolic': 138, 'Diastolic': 88, 'Rate': 67}, {'Systolic': 124, 'Diastolic': 99, 'Rate': 110}, {'Systolic': 146, 'Diastolic': 90, 'Rate': 83}, {'Systolic': 126, 'Diastolic': 89, 'Rate': 93}, {'Systolic': 102, 'Diastolic': 73, 'Rate': 81}, {'Systolic': 143, 'Diastolic': 84, 'Rate': 92}]}
# {'_id': 27, 'office_num': [6], 'patient_info': {'fname': 'Jack', 'lname': 'Carmichael'}, 'patient_numbers': ['922-222-3850', '107-357-3339'], 'weights': [114], 'height': 196, 'bp_readings': [{'Systolic': 124, 'Diastolic': 88, 'Rate': 69}, {'Systolic': 137, 'Diastolic': 95, 'Rate': 70}, {'Systolic': 138, 'Diastolic': 91, 'Rate': 84}, {'Systolic': 116, 'Diastolic': 91, 'Rate': 62}, {'Systolic': 105, 'Diastolic': 93, 'Rate': 91}, {'Systolic': 120, 'Diastolic': 85, 'Rate': 81}, {'Systolic': 142, 'Diastolic': 92, 'Rate': 88}, {'Systolic': 114, 'Diastolic': 93, 'Rate': 93}]}
# {'_id': 28, 'office_num': [3], 'patient_info': {'fname': 'Jordan', 'lname': 'Boone'}, 'patient_numbers': ['600-402-2361', '703-125-9247', '042-690-9986', '947-255-2383'], 'weights': [350, 186, 165, 269], 'height': 150, 'bp_readings': [{'Systolic': 115, 'Diastolic': 91, 'Rate': 62}, {'Systolic': 128, 'Diastolic': 97, 'Rate': 76}]}
# {'_id': 29, 'office_num': [7], 'patient_info': {'fname': 'Liam', 'lname': 'Carmichael'}, 'patient_numbers': ['099-667-7104', '238-147-8696', '151-967-6815', '639-311-3017'], 'weights': [378, 148, 309, 246, 385], 'height': 101, 'bp_readings': [{'Systolic': 149, 'Diastolic': 70, 'Rate': 71}, {'Systolic': 102, 'Diastolic': 78, 'Rate': 81}, {'Systolic': 118, 'Diastolic': 75, 'Rate': 109}]}
# {'_id': 30, 'office_num': [10], 'patient_info': {'fname': 'Susan', 'lname': 'Madden'}, 'patient_numbers': ['998-755-4608', '912-127-1347', '615-678-6037'], 'weights': [163], 'height': 167, 'bp_readings': [{'Systolic': 107, 'Diastolic': 80, 'Rate': 95}, {'Systolic': 117, 'Diastolic': 93, 'Rate': 82}, {'Systolic': 148, 'Diastolic': 88, 'Rate': 84}, {'Systolic': 148, 'Diastolic': 78, 'Rate': 81}, {'Systolic': 142, 'Diastolic': 96, 'Rate': 93}, {'Systolic': 122, 'Diastolic': 98, 'Rate': 79}, {'Systolic': 100, 'Diastolic': 91, 'Rate': 91}]}
# {'_id': 31, 'office_num': [7], 'patient_info': {'fname': 'Jerry', 'lname': 'Smith'}, 'patient_numbers': ['262-421-0396', '176-511-2539', '532-214-9994'], 'weights': [245, 165], 'height': 185, 'bp_readings': [{'Systolic': 144, 'Diastolic': 95, 'Rate': 104}, {'Systolic': 103, 'Diastolic': 93, 'Rate': 67}, {'Systolic': 118, 'Diastolic': 78, 'Rate': 94}, {'Systolic': 148, 'Diastolic': 94, 'Rate': 91}, {'Systolic': 148, 'Diastolic': 81, 'Rate': 74}, {'Systolic': 112, 'Diastolic': 75, 'Rate': 108}, {'Systolic': 141, 'Diastolic': 77, 'Rate': 83}, {'Systolic': 104, 'Diastolic': 78, 'Rate': 64}, {'Systolic': 119, 'Diastolic': 96, 'Rate': 62}, {'Systolic': 141, 'Diastolic': 77, 'Rate': 75}]}
# {'_id': 32, 'office_num': [6], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Boone'}, 'patient_numbers': ['943-580-4681', '928-893-4733', '454-098-3527'], 'weights': [251, 355, 320, 162, 195], 'height': 165, 'bp_readings': [{'Systolic': 130, 'Diastolic': 76, 'Rate': 93}, {'Systolic': 101, 'Diastolic': 80, 'Rate': 61}, {'Systolic': 121, 'Diastolic': 99, 'Rate': 106}, {'Systolic': 105, 'Diastolic': 74, 'Rate': 100}, {'Systolic': 131, 'Diastolic': 81, 'Rate': 62}, {'Systolic': 135, 'Diastolic': 91, 'Rate': 107}]}
# {'_id': 33, 'office_num': [9], 'patient_info': {'fname': 'Jordan', 'lname': 'Madden'}, 'patient_numbers': ['353-951-1045', '987-664-6622', '432-716-1605'], 'weights': [164, 336, 266, 177], 'height': 195, 'bp_readings': [{'Systolic': 105, 'Diastolic': 86, 'Rate': 87}, {'Systolic': 113, 'Diastolic': 84, 'Rate': 102}, {'Systolic': 136, 'Diastolic': 70, 'Rate': 102}, {'Systolic': 103, 'Diastolic': 83, 'Rate': 85}, {'Systolic': 126, 'Diastolic': 72, 'Rate': 104}, {'Systolic': 119, 'Diastolic': 90, 'Rate': 94}, {'Systolic': 103, 'Diastolic': 81, 'Rate': 110}]}
# {'_id': 34, 'office_num': [10], 'patient_info': {'fname': 'James', 'lname': 'Granger'}, 'patient_numbers': ['899-445-5394', '653-697-6167', '942-913-8573', '170-374-0124'], 'weights': [269], 'height': 199, 'bp_readings': [{'Systolic': 119, 'Diastolic': 71, 'Rate': 77}, {'Systolic': 101, 'Diastolic': 98, 'Rate': 67}, {'Systolic': 111, 'Diastolic': 90, 'Rate': 97}, {'Systolic': 103, 'Diastolic': 97, 'Rate': 102}]}
# {'_id': 35, 'office_num': [5], 'patient_info': {'fname': 'Jordan', 'lname': 'Hart'}, 'patient_numbers': ['337-795-4365', '024-735-2483', '143-077-5758'], 'weights': [208, 309, 395], 'height': 197, 'bp_readings': [{'Systolic': 137, 'Diastolic': 97, 'Rate': 78}, {'Systolic': 118, 'Diastolic': 83, 'Rate': 82}, {'Systolic': 120, 'Diastolic': 92, 'Rate': 64}, {'Systolic': 106, 'Diastolic': 99, 'Rate': 95}, {'Systolic': 145, 'Diastolic': 97, 'Rate': 93}, {'Systolic': 141, 'Diastolic': 94, 'Rate': 80}]}
# {'_id': 36, 'office_num': [6], 'patient_info': {'fname': 'John', 'lname': 'Boone'}, 'patient_numbers': ['481-493-6784', '404-065-5271', '838-613-4618', '554-889-0895'], 'weights': [257, 110], 'height': 100, 'bp_readings': [{'Systolic': 143, 'Diastolic': 86, 'Rate': 78}, {'Systolic': 136, 'Diastolic': 95, 'Rate': 69}]}
# {'_id': 37, 'office_num': [2], 'patient_info': {'fname': 'John', 'lname': ' Fox'}, 'patient_numbers': ['732-941-7923', '952-938-0091'], 'weights': [205, 306, 155], 'height': 123, 'bp_readings': [{'Systolic': 127, 'Diastolic': 93, 'Rate': 100}, {'Systolic': 131, 'Diastolic': 74, 'Rate': 90}, {'Systolic': 139, 'Diastolic': 70, 'Rate': 68}, {'Systolic': 109, 'Diastolic': 85, 'Rate': 83}, {'Systolic': 127, 'Diastolic': 75, 'Rate': 89}, {'Systolic': 142, 'Diastolic': 94, 'Rate': 88}, {'Systolic': 147, 'Diastolic': 88, 'Rate': 109}, {'Systolic': 114, 'Diastolic': 79, 'Rate': 77}, {'Systolic': 104, 'Diastolic': 79, 'Rate': 98}, {'Systolic': 131, 'Diastolic': 87, 'Rate': 90}]}
# {'_id': 38, 'office_num': [7], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hale'}, 'patient_numbers': ['402-808-6065', '335-325-8871', '004-462-5268', '560-175-4182'], 'weights': [345, 330, 323], 'height': 162, 'bp_readings': [{'Systolic': 131, 'Diastolic': 98, 'Rate': 106}, {'Systolic': 134, 'Diastolic': 86, 'Rate': 86}, {'Systolic': 114, 'Diastolic': 82, 'Rate': 81}, {'Systolic': 105, 'Diastolic': 73, 'Rate': 65}, {'Systolic': 138, 'Diastolic': 80, 'Rate': 102}, {'Systolic': 113, 'Diastolic': 74, 'Rate': 74}, {'Systolic': 117, 'Diastolic': 73, 'Rate': 62}, {'Systolic': 114, 'Diastolic': 80, 'Rate': 83}]}
# {'_id': 39, 'office_num': [4], 'patient_info': {'fname': 'Liam', 'lname': 'Granger'}, 'patient_numbers': ['107-340-1835', '503-102-1576', '196-857-9140', '060-033-1231'], 'weights': [223, 197, 219], 'height': 182, 'bp_readings': [{'Systolic': 128, 'Diastolic': 93, 'Rate': 93}, {'Systolic': 143, 'Diastolic': 73, 'Rate': 102}, {'Systolic': 146, 'Diastolic': 77, 'Rate': 109}, {'Systolic': 149, 'Diastolic': 98, 'Rate': 74}, {'Systolic': 104, 'Diastolic': 97, 'Rate': 96}, {'Systolic': 142, 'Diastolic': 78, 'Rate': 103}, {'Systolic': 116, 'Diastolic': 71, 'Rate': 83}, {'Systolic': 150, 'Diastolic': 88, 'Rate': 106}]}
# {'_id': 40, 'office_num': [2], 'patient_info': {'fname': 'Ethan', 'lname': 'Carmichael'}, 'patient_numbers': ['733-696-5824', '250-755-2885', '788-696-4643'], 'weights': [173, 270, 290], 'height': 163, 'bp_readings': [{'Systolic': 130, 'Diastolic': 99, 'Rate': 69}, {'Systolic': 148, 'Diastolic': 99, 'Rate': 76}]}
# {'_id': 41, 'office_num': [3], 'patient_info': {'fname': 'James', 'lname': 'Granger'}, 'patient_numbers': ['298-578-1231', '257-581-0499', '438-595-3544', '708-556-1065'], 'weights': [155, 296, 319], 'height': 116, 'bp_readings': [{'Systolic': 144, 'Diastolic': 84, 'Rate': 61}, {'Systolic': 116, 'Diastolic': 90, 'Rate': 108}, {'Systolic': 106, 'Diastolic': 70, 'Rate': 102}]}
# {'_id': 42, 'office_num': [6], 'patient_info': {'fname': 'Tom', 'lname': 'Smith'}, 'patient_numbers': ['204-314-4117', '216-490-4273', '400-450-7779'], 'weights': [233], 'height': 133, 'bp_readings': [{'Systolic': 100, 'Diastolic': 88, 'Rate': 100}, {'Systolic': 145, 'Diastolic': 92, 'Rate': 68}]}
# {'_id': 43, 'office_num': [6], 'patient_info': {'fname': 'Richard', 'lname': 'Hart'}, 'patient_numbers': ['603-651-9269', '290-646-5844'], 'weights': [237, 162, 236], 'height': 166, 'bp_readings': [{'Systolic': 114, 'Diastolic': 86, 'Rate': 68}, {'Systolic': 107, 'Diastolic': 94, 'Rate': 66}, {'Systolic': 109, 'Diastolic': 83, 'Rate': 94}, {'Systolic': 112, 'Diastolic': 73, 'Rate': 61}]}
# {'_id': 44, 'office_num': [1], 'patient_info': {'fname': 'Tom', 'lname': ' Fox'}, 'patient_numbers': ['634-367-5927', '699-948-2449', '955-420-7378', '971-007-8508'], 'weights': [216], 'height': 124, 'bp_readings': [{'Systolic': 130, 'Diastolic': 87, 'Rate': 72}, {'Systolic': 149, 'Diastolic': 77, 'Rate': 91}, {'Systolic': 106, 'Diastolic': 76, 'Rate': 69}, {'Systolic': 136, 'Diastolic': 76, 'Rate': 98}, {'Systolic': 142, 'Diastolic': 92, 'Rate': 70}, {'Systolic': 107, 'Diastolic': 79, 'Rate': 78}, {'Systolic': 133, 'Diastolic': 98, 'Rate': 74}, {'Systolic': 143, 'Diastolic': 77, 'Rate': 95}, {'Systolic': 142, 'Diastolic': 88, 'Rate': 84}]}
# {'_id': 45, 'office_num': [9], 'patient_info': {'fname': 'Tom', 'lname': 'Hart'}, 'patient_numbers': ['510-047-2711', '076-727-8526', '078-775-7391'], 'weights': [347, 238, 379, 172], 'height': 157, 'bp_readings': [{'Systolic': 105, 'Diastolic': 95, 'Rate': 110}, {'Systolic': 127, 'Diastolic': 73, 'Rate': 88}, {'Systolic': 130, 'Diastolic': 93, 'Rate': 60}, {'Systolic': 145, 'Diastolic': 96, 'Rate': 104}]}
# {'_id': 46, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': 'Madden'}, 'patient_numbers': ['389-395-5018', '590-930-9996', '046-414-5670', '565-111-8620'], 'weights': [377, 374], 'height': 169, 'bp_readings': [{'Systolic': 141, 'Diastolic': 97, 'Rate': 91}, {'Systolic': 121, 'Diastolic': 86, 'Rate': 96}, {'Systolic': 107, 'Diastolic': 83, 'Rate': 101}, {'Systolic': 143, 'Diastolic': 75, 'Rate': 88}, {'Systolic': 146, 'Diastolic': 94, 'Rate': 62}, {'Systolic': 130, 'Diastolic': 87, 'Rate': 69}, {'Systolic': 149, 'Diastolic': 95, 'Rate': 97}]}
# {'_id': 47, 'office_num': [8], 'patient_info': {'fname': 'John', 'lname': 'Madden'}, 'patient_numbers': ['948-454-3784', '471-101-9200', '658-314-1395'], 'weights': [301, 344, 301, 215], 'height': 182, 'bp_readings': [{'Systolic': 139, 'Diastolic': 90, 'Rate': 69}, {'Systolic': 141, 'Diastolic': 79, 'Rate': 71}, {'Systolic': 130, 'Diastolic': 89, 'Rate': 76}, {'Systolic': 129, 'Diastolic': 86, 'Rate': 77}, {'Systolic': 138, 'Diastolic': 87, 'Rate': 81}, {'Systolic': 126, 'Diastolic': 83, 'Rate': 108}, {'Systolic': 126, 'Diastolic': 81, 'Rate': 86}, {'Systolic': 119, 'Diastolic': 75, 'Rate': 105}, {'Systolic': 127, 'Diastolic': 81, 'Rate': 107}, {'Systolic': 132, 'Diastolic': 86, 'Rate': 101}]}
# {'_id': 48, 'office_num': [2], 'patient_info': {'fname': 'Tom', 'lname': 'Madden'}, 'patient_numbers': ['786-435-5175', '478-890-0956', '450-279-6450'], 'weights': [253], 'height': 163, 'bp_readings': [{'Systolic': 110, 'Diastolic': 99, 'Rate': 89}, {'Systolic': 119, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 141, 'Diastolic': 99, 'Rate': 61}, {'Systolic': 146, 'Diastolic': 99, 'Rate': 98}]}
# {'_id': 49, 'office_num': [4], 'patient_info': {'fname': 'Jordan', 'lname': ' Fox'}, 'patient_numbers': ['342-970-1408', '044-610-9496', '913-678-0331'], 'weights': [293, 384, 216, 332], 'height': 142, 'bp_readings': [{'Systolic': 131, 'Diastolic': 81, 'Rate': 82}, {'Systolic': 122, 'Diastolic': 81, 'Rate': 61}, {'Systolic': 140, 'Diastolic': 94, 'Rate': 60}, {'Systolic': 131, 'Diastolic': 85, 'Rate': 78}, {'Systolic': 140, 'Diastolic': 80, 'Rate': 61}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "428-197-6514",
#         "682-094-9620",
#         "642-487-2807"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 85,
#             "Rate": 108
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 98,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 82,
#             "Rate": 62
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 99
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 72
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 82
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "428-197-6514",
#         "682-094-9620",
#         "642-487-2807"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 85,
#             "Rate": 108
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 98,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 82,
#             "Rate": 62
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 99
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 72
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 82
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "428-197-6514",
#         "682-094-9620",
#         "642-487-2807"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 85,
#             "Rate": 108
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 98,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 82,
#             "Rate": 62
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 99
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 72
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 82
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^707'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %%
query = { "bp_readings": {"Systolic" : 104 , "Diastolic": 82, "Rate": 81}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 104}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 142} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 7,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "812-766-1297",
#         "491-650-1592",
#         "109-200-6643",
#         "660-432-9141"
#     ],
#     "weights": [
#         160
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 91,
#             "Rate": 82
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 81,
#             "Rate": 91
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 95,
#             "Rate": 102
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 82,
#             "Rate": 76
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 88,
#             "Rate": 82
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 97,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "987-090-9857",
#         "141-196-9110",
#         "190-909-3585",
#         "565-915-2229"
#     ],
#     "weights": [
#         310,
#         361,
#         275
#     ],
#     "height": 103,
#     "bp_readings": [
#         {
#             "Systolic": 113,
#             "Diastolic": 88,
#             "Rate": 99
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 64
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 97,
#             "Rate": 87
#         }
#     ]
# }
# {
#     "_id": 23,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "369-446-8443",
#         "410-304-7750",
#         "825-486-9958",
#         "524-016-6964"
#     ],
#     "weights": [
#         324,
#         307
#     ],
#     "height": 106,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 82,
#             "Rate": 68
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 93,
#             "Rate": 64
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 78,
#             "Rate": 95
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 83,
#             "Rate": 108
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 94,
#             "Rate": 73
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 86,
#             "Rate": 107
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 87,
#             "Rate": 76
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 81,
#             "Rate": 66
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 74
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "667-099-5859",
#         "108-001-9079",
#         "381-089-1766"
#     ],
#     "weights": [
#         391,
#         264,
#         120,
#         282
#     ],
#     "height": 123,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 96,
#             "Rate": 83
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 73,
#             "Rate": 64
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 98,
#             "Rate": 63
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 78
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 73
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 77,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "922-222-3850",
#         "107-357-3339"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 124,
#             "Diastolic": 88,
#             "Rate": 69
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 95,
#             "Rate": 70
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 91,
#             "Rate": 84
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 91,
#             "Rate": 62
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 93,
#             "Rate": 91
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 85,
#             "Rate": 81
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 92,
#             "Rate": 88
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "998-755-4608",
#         "912-127-1347",
#         "615-678-6037"
#     ],
#     "weights": [
#         163
#     ],
#     "height": 167,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 80,
#             "Rate": 95
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 82
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 88,
#             "Rate": 84
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 78,
#             "Rate": 81
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 96,
#             "Rate": 93
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 79
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 91,
#             "Rate": 91
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "732-941-7923",
#         "952-938-0091"
#     ],
#     "weights": [
#         205,
#         306,
#         155
#     ],
#     "height": 123,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 93,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 74,
#             "Rate": 90
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 70,
#             "Rate": 68
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 85,
#             "Rate": 83
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 75,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 94,
#             "Rate": 88
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 109
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 79,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "107-340-1835",
#         "503-102-1576",
#         "196-857-9140",
#         "060-033-1231"
#     ],
#     "weights": [
#         223,
#         197,
#         219
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 93,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 73,
#             "Rate": 102
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 77,
#             "Rate": 109
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "634-367-5927",
#         "699-948-2449",
#         "955-420-7378",
#         "971-007-8508"
#     ],
#     "weights": [
#         216
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 87,
#             "Rate": 72
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 77,
#             "Rate": 91
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 76,
#             "Rate": 69
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 76,
#             "Rate": 98
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 79,
#             "Rate": 78
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 77,
#             "Rate": 95
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 88,
#             "Rate": 84
#         }
#     ]
# }

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "428-197-6514",
#         "682-094-9620",
#         "642-487-2807"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 85,
#             "Rate": 108
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 98,
#             "Rate": 107
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 82,
#             "Rate": 62
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 70
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 99
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 90,
#             "Rate": 87
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 72
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 97,
#             "Rate": 82
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 2,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "330-584-3338",
#         "415-375-0832"
#     ],
#     "weights": [
#         328,
#         295,
#         352,
#         351,
#         332
#     ],
#     "height": 190,
#     "bp_readings": [
#         {
#             "Systolic": 147,
#             "Diastolic": 94,
#             "Rate": 109
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 88,
#             "Rate": 75
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 94,
#             "Rate": 86
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 99,
#             "Rate": 78
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 77,
#             "Rate": 104
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 75,
#             "Rate": 83
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 98,
#             "Rate": 91
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 70,
#             "Rate": 100
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 90,
#             "Rate": 110
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 79,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 3,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "026-379-7912",
#         "724-783-2689",
#         "853-048-8627",
#         "223-949-1900"
#     ],
#     "weights": [
#         225
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 90,
#             "Rate": 101
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 87,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 4,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "325-874-0334",
#         "844-258-5821"
#     ],
#     "weights": [
#         375,
#         180,
#         234,
#         318,
#         244
#     ],
#     "height": 181,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 93,
#             "Rate": 67
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 70,
#             "Rate": 105
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 84,
#             "Rate": 107
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 85,
#             "Rate": 66
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 84,
#             "Rate": 75
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 73,
#             "Rate": 93
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 98,
#             "Rate": 75
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 71,
#             "Rate": 107
#         }
#     ]
# }
# {
#     "_id": 5,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "832-070-2125",
#         "671-020-4408"
#     ],
#     "weights": [
#         98
#     ],
#     "height": 100,
#     "bp_readings": [
#         {
#             "Systolic": 117,
#             "Diastolic": 77,
#             "Rate": 90
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 71,
#             "Rate": 87
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 98
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 73,
#             "Rate": 86
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 85,
#             "Rate": 66
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 78,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 91,
#             "Rate": 96
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 74,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "905-970-6550",
#         "772-875-1518",
#         "398-548-6975",
#         "515-125-6338"
#     ],
#     "weights": [
#         135,
#         337,
#         290,
#         172
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 117,
#             "Diastolic": 78,
#             "Rate": 98
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 99,
#             "Rate": 73
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 92,
#             "Rate": 68
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 93,
#             "Rate": 61
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 88,
#             "Rate": 86
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 83,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "812-766-1297",
#         "491-650-1592",
#         "109-200-6643",
#         "660-432-9141"
#     ],
#     "weights": [
#         160
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 91,
#             "Rate": 82
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 81,
#             "Rate": 91
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 95,
#             "Rate": 102
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 82,
#             "Rate": 76
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 88,
#             "Rate": 82
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 97,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "102-359-7615",
#         "953-103-2060"
#     ],
#     "weights": [
#         369,
#         94,
#         146,
#         319
#     ],
#     "height": 178,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 85,
#             "Rate": 96
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 79,
#             "Rate": 62
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 91,
#             "Rate": 82
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 60
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 73,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "983-839-0125",
#         "513-601-3255",
#         "498-830-7389",
#         "742-807-3647"
#     ],
#     "weights": [
#         364,
#         296,
#         244
#     ],
#     "height": 165,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 99,
#             "Rate": 75
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 91,
#             "Rate": 80
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 94,
#             "Rate": 68
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 71,
#             "Rate": 62
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 99,
#             "Rate": 66
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 91,
#             "Rate": 103
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 74,
#             "Rate": 77
#         }
#     ]
# }
# {
#     "_id": 10,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "845-379-8843",
#         "029-833-8590",
#         "289-985-9290"
#     ],
#     "weights": [
#         150,
#         117,
#         323
#     ],
#     "height": 188,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 98,
#             "Rate": 88
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 97,
#             "Rate": 94
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 80,
#             "Rate": 62
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 85,
#             "Rate": 81
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 82,
#             "Rate": 99
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 82,
#             "Rate": 100
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 81,
#             "Rate": 60
#         }
#     ]
# }
# {
#     "_id": 11,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "257-519-5978",
#         "310-512-3322",
#         "075-967-8363",
#         "312-232-3687"
#     ],
#     "weights": [
#         358,
#         286,
#         345,
#         225
#     ],
#     "height": 111,
#     "bp_readings": [
#         {
#             "Systolic": 118,
#             "Diastolic": 73,
#             "Rate": 77
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 92,
#             "Rate": 84
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 97,
#             "Rate": 67
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 90,
#             "Rate": 90
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 84,
#             "Rate": 63
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 83,
#             "Rate": 110
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 86,
#             "Rate": 63
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 98,
#             "Rate": 108
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 70,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "166-119-7349",
#         "459-618-2479",
#         "742-755-6140",
#         "259-737-1478"
#     ],
#     "weights": [
#         374,
#         272,
#         204,
#         275
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 95,
#             "Rate": 67
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 72,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "470-215-7864",
#         "993-649-9534"
#     ],
#     "weights": [
#         277,
#         189,
#         202
#     ],
#     "height": 198,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 95,
#             "Rate": 63
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 90,
#             "Rate": 72
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 84,
#             "Rate": 77
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 93,
#             "Rate": 104
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 87,
#             "Rate": 88
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 86,
#             "Rate": 99
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 76,
#             "Rate": 99
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "737-198-8430",
#         "980-236-4727",
#         "910-643-9695",
#         "140-238-4980"
#     ],
#     "weights": [
#         163
#     ],
#     "height": 157,
#     "bp_readings": [
#         {
#             "Systolic": 145,
#             "Diastolic": 90,
#             "Rate": 91
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 74,
#             "Rate": 76
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 84,
#             "Rate": 110
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 80
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 87,
#             "Rate": 98
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 92,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "419-192-6354",
#         "536-047-6128",
#         "854-304-0720",
#         "745-795-1956"
#     ],
#     "weights": [
#         334,
#         147,
#         300,
#         265
#     ],
#     "height": 200,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 99,
#             "Rate": 91
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 93,
#             "Rate": 89
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 75,
#             "Rate": 73
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 74,
#             "Rate": 105
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 79,
#             "Rate": 96
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 86,
#             "Rate": 85
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 83,
#             "Rate": 96
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 88,
#             "Rate": 101
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 73,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "987-090-9857",
#         "141-196-9110",
#         "190-909-3585",
#         "565-915-2229"
#     ],
#     "weights": [
#         310,
#         361,
#         275
#     ],
#     "height": 103,
#     "bp_readings": [
#         {
#             "Systolic": 113,
#             "Diastolic": 88,
#             "Rate": 99
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 94,
#             "Rate": 64
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 79,
#             "Rate": 63
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 97,
#             "Rate": 87
#         }
#     ]
# }
# {
#     "_id": 17,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "782-348-8742",
#         "188-304-9286",
#         "675-225-8938",
#         "389-246-5387"
#     ],
#     "weights": [
#         110,
#         117,
#         353,
#         98,
#         200
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 84,
#             "Rate": 93
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 75,
#             "Rate": 100
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "056-124-1055",
#         "856-505-3190"
#     ],
#     "weights": [
#         326,
#         392,
#         390,
#         244
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 95,
#             "Rate": 62
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 109
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 95,
#             "Rate": 88
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 81
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 107
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 60
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 81
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 96,
#             "Rate": 95
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 82,
#             "Rate": 75
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 82,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 20,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "116-087-7438",
#         "108-723-9743",
#         "330-487-2243",
#         "746-830-0925"
#     ],
#     "weights": [
#         246,
#         269,
#         161
#     ],
#     "height": 115,
#     "bp_readings": [
#         {
#             "Systolic": 133,
#             "Diastolic": 77,
#             "Rate": 85
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 82,
#             "Rate": 86
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 97,
#             "Rate": 78
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 99,
#             "Rate": 72
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 96,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "851-769-5203",
#         "088-464-0425"
#     ],
#     "weights": [
#         267,
#         123,
#         96,
#         335
#     ],
#     "height": 143,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 98,
#             "Rate": 104
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 81,
#             "Rate": 82
#         }
#     ]
# }
# {
#     "_id": 23,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "369-446-8443",
#         "410-304-7750",
#         "825-486-9958",
#         "524-016-6964"
#     ],
#     "weights": [
#         324,
#         307
#     ],
#     "height": 106,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 82,
#             "Rate": 68
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 93,
#             "Rate": 64
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 78,
#             "Rate": 95
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 83,
#             "Rate": 108
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 94,
#             "Rate": 73
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 86,
#             "Rate": 107
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 87,
#             "Rate": 76
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 81,
#             "Rate": 66
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 77,
#             "Rate": 74
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "667-099-5859",
#         "108-001-9079",
#         "381-089-1766"
#     ],
#     "weights": [
#         391,
#         264,
#         120,
#         282
#     ],
#     "height": 123,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 96,
#             "Rate": 83
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 73,
#             "Rate": 64
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 98,
#             "Rate": 63
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 78
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 73
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 77,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 25,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "855-210-0926",
#         "180-863-6751",
#         "070-413-8714",
#         "865-042-9651"
#     ],
#     "weights": [
#         223,
#         348
#     ],
#     "height": 104,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 86,
#             "Rate": 96
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 77,
#             "Rate": 95
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "864-973-0653",
#         "167-621-3278",
#         "638-223-2052"
#     ],
#     "weights": [
#         160,
#         280,
#         142,
#         140
#     ],
#     "height": 173,
#     "bp_readings": [
#         {
#             "Systolic": 106,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 95,
#             "Rate": 63
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 88,
#             "Rate": 67
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 99,
#             "Rate": 110
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 90,
#             "Rate": 83
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 89,
#             "Rate": 93
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 73,
#             "Rate": 81
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 84,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "922-222-3850",
#         "107-357-3339"
#     ],
#     "weights": [
#         114
#     ],
#     "height": 196,
#     "bp_readings": [
#         {
#             "Systolic": 124,
#             "Diastolic": 88,
#             "Rate": 69
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 95,
#             "Rate": 70
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 91,
#             "Rate": 84
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 91,
#             "Rate": 62
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 93,
#             "Rate": 91
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 85,
#             "Rate": 81
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 92,
#             "Rate": 88
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 93,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "099-667-7104",
#         "238-147-8696",
#         "151-967-6815",
#         "639-311-3017"
#     ],
#     "weights": [
#         378,
#         148,
#         309,
#         246,
#         385
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 70,
#             "Rate": 71
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 78,
#             "Rate": 81
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 75,
#             "Rate": 109
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "998-755-4608",
#         "912-127-1347",
#         "615-678-6037"
#     ],
#     "weights": [
#         163
#     ],
#     "height": 167,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 80,
#             "Rate": 95
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 82
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 88,
#             "Rate": 84
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 78,
#             "Rate": 81
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 96,
#             "Rate": 93
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 98,
#             "Rate": 79
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 91,
#             "Rate": 91
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "262-421-0396",
#         "176-511-2539",
#         "532-214-9994"
#     ],
#     "weights": [
#         245,
#         165
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 95,
#             "Rate": 104
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 93,
#             "Rate": 67
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 78,
#             "Rate": 94
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 94,
#             "Rate": 91
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 75,
#             "Rate": 108
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 83
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 78,
#             "Rate": 64
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 96,
#             "Rate": 62
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 75
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "943-580-4681",
#         "928-893-4733",
#         "454-098-3527"
#     ],
#     "weights": [
#         251,
#         355,
#         320,
#         162,
#         195
#     ],
#     "height": 165,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 76,
#             "Rate": 93
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 80,
#             "Rate": 61
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 99,
#             "Rate": 106
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 74,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 81,
#             "Rate": 62
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 91,
#             "Rate": 107
#         }
#     ]
# }
# {
#     "_id": 33,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "353-951-1045",
#         "987-664-6622",
#         "432-716-1605"
#     ],
#     "weights": [
#         164,
#         336,
#         266,
#         177
#     ],
#     "height": 195,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 86,
#             "Rate": 87
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 84,
#             "Rate": 102
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 70,
#             "Rate": 102
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 83,
#             "Rate": 85
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 72,
#             "Rate": 104
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 90,
#             "Rate": 94
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 81,
#             "Rate": 110
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "337-795-4365",
#         "024-735-2483",
#         "143-077-5758"
#     ],
#     "weights": [
#         208,
#         309,
#         395
#     ],
#     "height": 197,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 97,
#             "Rate": 78
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 83,
#             "Rate": 82
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 92,
#             "Rate": 64
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 99,
#             "Rate": 95
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 97,
#             "Rate": 93
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 94,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "481-493-6784",
#         "404-065-5271",
#         "838-613-4618",
#         "554-889-0895"
#     ],
#     "weights": [
#         257,
#         110
#     ],
#     "height": 100,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 86,
#             "Rate": 78
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 95,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "732-941-7923",
#         "952-938-0091"
#     ],
#     "weights": [
#         205,
#         306,
#         155
#     ],
#     "height": 123,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 93,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 74,
#             "Rate": 90
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 70,
#             "Rate": 68
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 85,
#             "Rate": 83
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 75,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 94,
#             "Rate": 88
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 109
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 79,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 38,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "402-808-6065",
#         "335-325-8871",
#         "004-462-5268",
#         "560-175-4182"
#     ],
#     "weights": [
#         345,
#         330,
#         323
#     ],
#     "height": 162,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 98,
#             "Rate": 106
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 86,
#             "Rate": 86
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 82,
#             "Rate": 81
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 73,
#             "Rate": 65
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 80,
#             "Rate": 102
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 74,
#             "Rate": 74
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 73,
#             "Rate": 62
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 80,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "107-340-1835",
#         "503-102-1576",
#         "196-857-9140",
#         "060-033-1231"
#     ],
#     "weights": [
#         223,
#         197,
#         219
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 93,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 73,
#             "Rate": 102
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 77,
#             "Rate": 109
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "733-696-5824",
#         "250-755-2885",
#         "788-696-4643"
#     ],
#     "weights": [
#         173,
#         270,
#         290
#     ],
#     "height": 163,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 99,
#             "Rate": 69
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 99,
#             "Rate": 76
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "298-578-1231",
#         "257-581-0499",
#         "438-595-3544",
#         "708-556-1065"
#     ],
#     "weights": [
#         155,
#         296,
#         319
#     ],
#     "height": 116,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 84,
#             "Rate": 61
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 90,
#             "Rate": 108
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 70,
#             "Rate": 102
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "204-314-4117",
#         "216-490-4273",
#         "400-450-7779"
#     ],
#     "weights": [
#         233
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 88,
#             "Rate": 100
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 92,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "634-367-5927",
#         "699-948-2449",
#         "955-420-7378",
#         "971-007-8508"
#     ],
#     "weights": [
#         216
#     ],
#     "height": 124,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 87,
#             "Rate": 72
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 77,
#             "Rate": 91
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 76,
#             "Rate": 69
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 76,
#             "Rate": 98
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 79,
#             "Rate": 78
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 77,
#             "Rate": 95
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 88,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "510-047-2711",
#         "076-727-8526",
#         "078-775-7391"
#     ],
#     "weights": [
#         347,
#         238,
#         379,
#         172
#     ],
#     "height": 157,
#     "bp_readings": [
#         {
#             "Systolic": 105,
#             "Diastolic": 95,
#             "Rate": 110
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 73,
#             "Rate": 88
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 93,
#             "Rate": 60
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 96,
#             "Rate": 104
#         }
#     ]
# }
# {
#     "_id": 46,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "389-395-5018",
#         "590-930-9996",
#         "046-414-5670",
#         "565-111-8620"
#     ],
#     "weights": [
#         377,
#         374
#     ],
#     "height": 169,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 97,
#             "Rate": 91
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 86,
#             "Rate": 96
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 83,
#             "Rate": 101
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 88
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 94,
#             "Rate": 62
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 87,
#             "Rate": 69
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 95,
#             "Rate": 97
#         }
#     ]
# }
# {
#     "_id": 47,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "948-454-3784",
#         "471-101-9200",
#         "658-314-1395"
#     ],
#     "weights": [
#         301,
#         344,
#         301,
#         215
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 139,
#             "Diastolic": 90,
#             "Rate": 69
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 79,
#             "Rate": 71
#         },
#         {
#             "Systolic": 130,
#             "Diastolic": 89,
#             "Rate": 76
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 86,
#             "Rate": 77
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 87,
#             "Rate": 81
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 83,
#             "Rate": 108
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 81,
#             "Rate": 86
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 75,
#             "Rate": 105
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 81,
#             "Rate": 107
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 86,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 48,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "786-435-5175",
#         "478-890-0956",
#         "450-279-6450"
#     ],
#     "weights": [
#         253
#     ],
#     "height": 163,
#     "bp_readings": [
#         {
#             "Systolic": 110,
#             "Diastolic": 99,
#             "Rate": 89
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 99,
#             "Rate": 61
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 99,
#             "Rate": 98
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "342-970-1408",
#         "044-610-9496",
#         "913-678-0331"
#     ],
#     "weights": [
#         293,
#         384,
#         216,
#         332
#     ],
#     "height": 142,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 81,
#             "Rate": 82
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 81,
#             "Rate": 61
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 94,
#             "Rate": 60
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 85,
#             "Rate": 78
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 80,
#             "Rate": 61
#         }
#     ]
# }

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 7,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "812-766-1297",
#         "491-650-1592",
#         "109-200-6643",
#         "660-432-9141"
#     ],
#     "weights": [
#         160
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 91,
#             "Rate": 82
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 81,
#             "Rate": 91
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 84,
#             "Rate": 79
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 95,
#             "Rate": 102
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 82,
#             "Rate": 76
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 88,
#             "Rate": 82
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 77,
#             "Rate": 69
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 97,
#             "Rate": 61
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "166-119-7349",
#         "459-618-2479",
#         "742-755-6140",
#         "259-737-1478"
#     ],
#     "weights": [
#         374,
#         272,
#         204,
#         275
#     ],
#     "height": 112,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 95,
#             "Rate": 67
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 72,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "056-124-1055",
#         "856-505-3190"
#     ],
#     "weights": [
#         326,
#         392,
#         390,
#         244
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 95,
#             "Rate": 62
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 109
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 95,
#             "Rate": 88
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 81
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 107
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 60
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 81
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 96,
#             "Rate": 95
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 82,
#             "Rate": 75
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 82,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "262-421-0396",
#         "176-511-2539",
#         "532-214-9994"
#     ],
#     "weights": [
#         245,
#         165
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 95,
#             "Rate": 104
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 93,
#             "Rate": 67
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 78,
#             "Rate": 94
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 94,
#             "Rate": 91
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 75,
#             "Rate": 108
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 83
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 78,
#             "Rate": 64
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 96,
#             "Rate": 62
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 75
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "732-941-7923",
#         "952-938-0091"
#     ],
#     "weights": [
#         205,
#         306,
#         155
#     ],
#     "height": 123,
#     "bp_readings": [
#         {
#             "Systolic": 127,
#             "Diastolic": 93,
#             "Rate": 100
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 74,
#             "Rate": 90
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 70,
#             "Rate": 68
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 85,
#             "Rate": 83
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 75,
#             "Rate": 89
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 94,
#             "Rate": 88
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 109
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 79,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 79,
#             "Rate": 98
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 87,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "107-340-1835",
#         "503-102-1576",
#         "196-857-9140",
#         "060-033-1231"
#     ],
#     "weights": [
#         223,
#         197,
#         219
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 93,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 73,
#             "Rate": 102
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 77,
#             "Rate": 109
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 106
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 3,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "026-379-7912",
#         "724-783-2689",
#         "853-048-8627",
#         "223-949-1900"
#     ],
#     "weights": [
#         225
#     ],
#     "height": 185,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 90,
#             "Rate": 101
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 87,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "905-970-6550",
#         "772-875-1518",
#         "398-548-6975",
#         "515-125-6338"
#     ],
#     "weights": [
#         135,
#         337,
#         290,
#         172
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 117,
#             "Diastolic": 78,
#             "Rate": 98
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 99,
#             "Rate": 73
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 92,
#             "Rate": 68
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 93,
#             "Rate": 61
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 88,
#             "Rate": 86
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 83,
#             "Rate": 78
#         }
#     ]
# }
# {
#     "_id": 8,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "102-359-7615",
#         "953-103-2060"
#     ],
#     "weights": [
#         369,
#         94,
#         146,
#         319
#     ],
#     "height": 178,
#     "bp_readings": [
#         {
#             "Systolic": 120,
#             "Diastolic": 85,
#             "Rate": 96
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 79,
#             "Rate": 62
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 91,
#             "Rate": 82
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 60
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 73,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "056-124-1055",
#         "856-505-3190"
#     ],
#     "weights": [
#         326,
#         392,
#         390,
#         244
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 95,
#             "Rate": 62
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 98,
#             "Rate": 109
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 95,
#             "Rate": 88
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 84,
#             "Rate": 81
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 107
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 76,
#             "Rate": 60
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 77,
#             "Rate": 81
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 96,
#             "Rate": 95
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 82,
#             "Rate": 75
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 82,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "107-340-1835",
#         "503-102-1576",
#         "196-857-9140",
#         "060-033-1231"
#     ],
#     "weights": [
#         223,
#         197,
#         219
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 128,
#             "Diastolic": 93,
#             "Rate": 93
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 73,
#             "Rate": 102
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 77,
#             "Rate": 109
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 98,
#             "Rate": 74
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 88,
#             "Rate": 106
#         }
#     ]
# }

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
