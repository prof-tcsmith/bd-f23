# %% [markdown]
# # Querrying a noSQL db (MongoDB)

# %% [markdown]
# MongoDB supports both basic and advanced CRUD operations (**C**reate **R**ead **U**pdate and **D**elete).
#
# In this notebook, we'll explore the **Read** operations - specifically, how to query an existing collection of documents in MongoDB.
#
# >NOTE: For more information on MongoDB's support for query operations, see [here]( https://docs.mongodb.com/manual/tutorial/query-documents/.).

# %% [markdown]
# ## Step 1: Establish a connection to the Database
#
# You will need to setup the client so that it connects to your project.
#
# Then, you'll need to specify the database within this project.
#
# Finally, you'll need to specify the collection within which you wish to make the query.

# %%
import pymongo # pymongo is a python driver for MongoDB

client = pymongo.MongoClient('mongodb://localhost:27017/')

db = client.cardio # # this is a database that was created in a previous notebook (4)
collection = db.patients # this is a collection that was created in a previous notebook (4)

# %% [markdown]
# ## Step2: Query the collection
#
# You can use many different approaches to querrying the collection.

# %% [markdown]
# ### Get all documents in a collection

# %%
import json  
query = {} # select all documents (same as select * from patients)
doc = collection.find(query)
for record in doc: # 'doc' is a cursor that we can iterate over
    print(record)
# Out:
# {'_id': 1, 'office_num': [3], 'patient_info': {'fname': 'Jordan', 'lname': 'Smith', 'mname': 'Jane'}, 'patient_numbers': ['177-763-1706', '690-743-9150', '008-063-6083'], 'weights': [343, 373, 209, 266], 'height': 129, 'bp_readings': [{'Systolic': 148, 'Diastolic': 84, 'Rate': 78}, {'Systolic': 101, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 141, 'Diastolic': 73, 'Rate': 71}, {'Systolic': 140, 'Diastolic': 93, 'Rate': 78}, {'Systolic': 107, 'Diastolic': 93, 'Rate': 81}], 'comments': 'good patient', 'readings': [{'Systolic': 999, 'Diastolic': 999, 'Rate': 999}]}
# {'_id': 2, 'office_num': [9], 'patient_info': {'fname': 'Liam', 'lname': 'Hale'}, 'patient_numbers': ['344-978-6907', '366-258-5178', '128-657-0704', '999-622-8303'], 'weights': [370, 208, 297, 353, 266], 'height': 173, 'bp_readings': [{'Systolic': 129, 'Diastolic': 99, 'Rate': 77}, {'Systolic': 142, 'Diastolic': 87, 'Rate': 98}, {'Systolic': 146, 'Diastolic': 70, 'Rate': 84}, {'Systolic': 150, 'Diastolic': 97, 'Rate': 107}, {'Systolic': 132, 'Diastolic': 95, 'Rate': 68}, {'Systolic': 133, 'Diastolic': 94, 'Rate': 95}, {'Systolic': 113, 'Diastolic': 83, 'Rate': 63}]}
# {'_id': 3, 'office_num': [8], 'patient_info': {'fname': 'Ethan', 'lname': 'Langston'}, 'patient_numbers': ['386-756-5088', '995-790-3289', '218-401-1070', '434-192-5412'], 'weights': [220, 360], 'height': 121, 'bp_readings': [{'Systolic': 141, 'Diastolic': 92, 'Rate': 78}, {'Systolic': 129, 'Diastolic': 92, 'Rate': 80}, {'Systolic': 131, 'Diastolic': 85, 'Rate': 67}, {'Systolic': 101, 'Diastolic': 79, 'Rate': 84}, {'Systolic': 121, 'Diastolic': 83, 'Rate': 110}, {'Systolic': 112, 'Diastolic': 78, 'Rate': 66}]}
# {'_id': 4, 'office_num': [5], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hale'}, 'patient_numbers': ['960-306-2027', '868-387-3806'], 'weights': [254, 308, 120, 242, 154], 'height': 127, 'bp_readings': [{'Systolic': 119, 'Diastolic': 72, 'Rate': 64}, {'Systolic': 119, 'Diastolic': 99, 'Rate': 79}]}
# {'_id': 5, 'office_num': [3], 'patient_info': {'fname': 'Liam', 'lname': 'Langston'}, 'patient_numbers': ['208-093-9729', '806-351-3969', '371-648-7059'], 'weights': [234, 99, 170, 192], 'height': 141, 'bp_readings': [{'Systolic': 121, 'Diastolic': 83, 'Rate': 73}, {'Systolic': 117, 'Diastolic': 91, 'Rate': 66}, {'Systolic': 124, 'Diastolic': 99, 'Rate': 95}, {'Systolic': 122, 'Diastolic': 99, 'Rate': 103}]}
# {'_id': 6, 'office_num': [9], 'patient_info': {'fname': 'Jack', 'lname': 'Hale'}, 'patient_numbers': ['101-222-8345', '984-555-1439'], 'weights': [159, 386, 372, 143], 'height': 141, 'bp_readings': [{'Systolic': 126, 'Diastolic': 72, 'Rate': 84}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 68}]}
# {'_id': 7, 'office_num': [6], 'patient_info': {'fname': 'Betty', 'lname': 'Langston'}, 'patient_numbers': ['619-839-1454', '981-741-0409', '016-103-3962', '172-321-6684'], 'weights': [219, 334, 251, 141, 196], 'height': 183, 'bp_readings': [{'Systolic': 102, 'Diastolic': 70, 'Rate': 60}, {'Systolic': 150, 'Diastolic': 99, 'Rate': 78}, {'Systolic': 146, 'Diastolic': 89, 'Rate': 80}, {'Systolic': 128, 'Diastolic': 82, 'Rate': 80}, {'Systolic': 125, 'Diastolic': 72, 'Rate': 64}, {'Systolic': 120, 'Diastolic': 89, 'Rate': 89}, {'Systolic': 107, 'Diastolic': 78, 'Rate': 73}]}
# {'_id': 8, 'office_num': [10], 'patient_info': {'fname': 'Tom', 'lname': 'Hale'}, 'patient_numbers': ['754-283-4335', '141-719-5364', '052-594-3518', '999-133-0361'], 'weights': [372, 126, 128], 'height': 102, 'bp_readings': [{'Systolic': 118, 'Diastolic': 94, 'Rate': 110}, {'Systolic': 122, 'Diastolic': 85, 'Rate': 90}]}
# {'_id': 9, 'office_num': [3], 'patient_info': {'fname': 'Betty', 'lname': 'Hale'}, 'patient_numbers': ['182-222-5418', '942-328-0598', '324-682-0341'], 'weights': [310, 371, 218, 367], 'height': 156, 'bp_readings': [{'Systolic': 129, 'Diastolic': 70, 'Rate': 85}, {'Systolic': 121, 'Diastolic': 75, 'Rate': 76}, {'Systolic': 131, 'Diastolic': 70, 'Rate': 110}, {'Systolic': 141, 'Diastolic': 99, 'Rate': 86}, {'Systolic': 136, 'Diastolic': 70, 'Rate': 63}, {'Systolic': 144, 'Diastolic': 81, 'Rate': 97}, {'Systolic': 108, 'Diastolic': 88, 'Rate': 68}, {'Systolic': 108, 'Diastolic': 78, 'Rate': 77}, {'Systolic': 125, 'Diastolic': 88, 'Rate': 85}, {'Systolic': 111, 'Diastolic': 89, 'Rate': 65}]}
# {'_id': 10, 'office_num': [4], 'patient_info': {'fname': 'Jack', 'lname': 'Jones'}, 'patient_numbers': ['858-733-5773', '658-943-0185'], 'weights': [351, 194], 'height': 139, 'bp_readings': [{'Systolic': 144, 'Diastolic': 79, 'Rate': 95}, {'Systolic': 123, 'Diastolic': 75, 'Rate': 104}, {'Systolic': 144, 'Diastolic': 93, 'Rate': 89}, {'Systolic': 138, 'Diastolic': 72, 'Rate': 67}, {'Systolic': 138, 'Diastolic': 86, 'Rate': 96}, {'Systolic': 124, 'Diastolic': 75, 'Rate': 69}]}
# {'_id': 11, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Granger'}, 'patient_numbers': ['076-568-2808', '141-412-9173', '666-257-2973', '169-861-4436'], 'weights': [92, 187, 360, 314, 386], 'height': 102, 'bp_readings': [{'Systolic': 140, 'Diastolic': 89, 'Rate': 75}, {'Systolic': 116, 'Diastolic': 76, 'Rate': 71}]}
# {'_id': 12, 'office_num': [5], 'patient_info': {'fname': 'July', 'lname': 'Hale'}, 'patient_numbers': ['449-472-8576', '139-634-1019'], 'weights': [369], 'height': 137, 'bp_readings': [{'Systolic': 104, 'Diastolic': 86, 'Rate': 83}, {'Systolic': 136, 'Diastolic': 95, 'Rate': 79}, {'Systolic': 127, 'Diastolic': 86, 'Rate': 103}, {'Systolic': 122, 'Diastolic': 94, 'Rate': 93}]}
# {'_id': 13, 'office_num': [6], 'patient_info': {'fname': 'John', 'lname': 'Smith'}, 'patient_numbers': ['754-865-9716', '638-049-8379', '864-279-8358'], 'weights': [289], 'height': 174, 'bp_readings': [{'Systolic': 125, 'Diastolic': 80, 'Rate': 99}, {'Systolic': 137, 'Diastolic': 93, 'Rate': 104}, {'Systolic': 147, 'Diastolic': 72, 'Rate': 91}, {'Systolic': 147, 'Diastolic': 77, 'Rate': 100}, {'Systolic': 141, 'Diastolic': 79, 'Rate': 100}, {'Systolic': 101, 'Diastolic': 83, 'Rate': 106}, {'Systolic': 140, 'Diastolic': 74, 'Rate': 100}, {'Systolic': 149, 'Diastolic': 99, 'Rate': 85}]}
# {'_id': 14, 'office_num': [5], 'patient_info': {'fname': 'July', 'lname': 'Smith'}, 'patient_numbers': ['054-684-2747', '278-048-1961', '517-028-2164', '943-833-5411'], 'weights': [278, 329, 351, 375, 115], 'height': 121, 'bp_readings': [{'Systolic': 141, 'Diastolic': 93, 'Rate': 105}, {'Systolic': 135, 'Diastolic': 78, 'Rate': 82}, {'Systolic': 139, 'Diastolic': 93, 'Rate': 74}, {'Systolic': 125, 'Diastolic': 87, 'Rate': 85}, {'Systolic': 111, 'Diastolic': 85, 'Rate': 110}, {'Systolic': 116, 'Diastolic': 97, 'Rate': 99}]}
# {'_id': 15, 'office_num': [6], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Granger'}, 'patient_numbers': ['930-965-6343', '129-792-9478', '222-754-6313'], 'weights': [124, 144, 206], 'height': 150, 'bp_readings': [{'Systolic': 131, 'Diastolic': 99, 'Rate': 66}, {'Systolic': 111, 'Diastolic': 71, 'Rate': 63}, {'Systolic': 138, 'Diastolic': 70, 'Rate': 108}, {'Systolic': 113, 'Diastolic': 91, 'Rate': 62}, {'Systolic': 131, 'Diastolic': 92, 'Rate': 93}, {'Systolic': 146, 'Diastolic': 98, 'Rate': 99}, {'Systolic': 128, 'Diastolic': 80, 'Rate': 102}]}
# {'_id': 16, 'office_num': [5], 'patient_info': {'fname': 'Betty', 'lname': 'Langston'}, 'patient_numbers': ['213-637-7623', '347-896-3745', '791-310-0075', '694-362-2006'], 'weights': [367, 119], 'height': 172, 'bp_readings': [{'Systolic': 116, 'Diastolic': 74, 'Rate': 65}, {'Systolic': 129, 'Diastolic': 90, 'Rate': 79}, {'Systolic': 100, 'Diastolic': 71, 'Rate': 94}, {'Systolic': 103, 'Diastolic': 86, 'Rate': 68}, {'Systolic': 102, 'Diastolic': 99, 'Rate': 77}, {'Systolic': 149, 'Diastolic': 73, 'Rate': 87}, {'Systolic': 105, 'Diastolic': 76, 'Rate': 61}, {'Systolic': 131, 'Diastolic': 90, 'Rate': 68}]}
# {'_id': 17, 'office_num': [5], 'patient_info': {'fname': 'Susan', 'lname': 'Granger'}, 'patient_numbers': ['765-443-3099', '256-988-0586', '838-614-9142', '120-360-0187'], 'weights': [279, 140, 250, 110, 154], 'height': 168, 'bp_readings': [{'Systolic': 128, 'Diastolic': 91, 'Rate': 68}, {'Systolic': 125, 'Diastolic': 94, 'Rate': 105}]}
# {'_id': 18, 'office_num': [8], 'patient_info': {'fname': 'John', 'lname': 'Hale'}, 'patient_numbers': ['145-140-6045', '246-141-6388', '355-869-7127'], 'weights': [376, 387, 356, 364, 105], 'height': 137, 'bp_readings': [{'Systolic': 112, 'Diastolic': 81, 'Rate': 84}, {'Systolic': 133, 'Diastolic': 80, 'Rate': 66}, {'Systolic': 126, 'Diastolic': 81, 'Rate': 68}, {'Systolic': 136, 'Diastolic': 72, 'Rate': 62}]}
# {'_id': 19, 'office_num': [5], 'patient_info': {'fname': 'Tom', 'lname': 'Hale'}, 'patient_numbers': ['645-545-8808', '125-559-1747', '756-190-2087'], 'weights': [218, 215, 383, 263, 275], 'height': 182, 'bp_readings': [{'Systolic': 125, 'Diastolic': 79, 'Rate': 89}, {'Systolic': 138, 'Diastolic': 80, 'Rate': 94}, {'Systolic': 132, 'Diastolic': 75, 'Rate': 61}, {'Systolic': 109, 'Diastolic': 78, 'Rate': 103}, {'Systolic': 114, 'Diastolic': 88, 'Rate': 68}, {'Systolic': 107, 'Diastolic': 75, 'Rate': 109}, {'Systolic': 126, 'Diastolic': 93, 'Rate': 99}]}
# {'_id': 20, 'office_num': [1], 'patient_info': {'fname': 'Tom', 'lname': 'Smith'}, 'patient_numbers': ['413-419-8113', '286-095-7433', '973-675-8371', '463-086-8716'], 'weights': [351, 386, 389, 307, 110], 'height': 145, 'bp_readings': [{'Systolic': 100, 'Diastolic': 76, 'Rate': 79}, {'Systolic': 144, 'Diastolic': 92, 'Rate': 101}, {'Systolic': 100, 'Diastolic': 87, 'Rate': 67}, {'Systolic': 119, 'Diastolic': 86, 'Rate': 107}, {'Systolic': 120, 'Diastolic': 94, 'Rate': 94}, {'Systolic': 141, 'Diastolic': 88, 'Rate': 95}, {'Systolic': 118, 'Diastolic': 86, 'Rate': 86}, {'Systolic': 134, 'Diastolic': 96, 'Rate': 93}, {'Systolic': 126, 'Diastolic': 89, 'Rate': 100}]}
# {'_id': 21, 'office_num': [10], 'patient_info': {'fname': 'Richard', 'lname': 'Boone'}, 'patient_numbers': ['287-928-2406', '905-664-0110', '647-457-5671'], 'weights': [271, 164, 302, 165], 'height': 102, 'bp_readings': [{'Systolic': 116, 'Diastolic': 81, 'Rate': 68}, {'Systolic': 137, 'Diastolic': 95, 'Rate': 78}, {'Systolic': 126, 'Diastolic': 78, 'Rate': 92}, {'Systolic': 118, 'Diastolic': 93, 'Rate': 86}]}
# {'_id': 22, 'office_num': [5], 'patient_info': {'fname': 'Liam', 'lname': 'Madden'}, 'patient_numbers': ['376-611-2323', '014-271-6201', '690-838-6501'], 'weights': [304, 150, 225, 232, 181], 'height': 161, 'bp_readings': [{'Systolic': 150, 'Diastolic': 76, 'Rate': 103}, {'Systolic': 141, 'Diastolic': 72, 'Rate': 84}]}
# {'_id': 23, 'office_num': [2], 'patient_info': {'fname': 'Susan', 'lname': 'Boone'}, 'patient_numbers': ['876-197-1269', '328-468-4783', '957-105-4087'], 'weights': [141, 207, 350], 'height': 135, 'bp_readings': [{'Systolic': 145, 'Diastolic': 77, 'Rate': 86}, {'Systolic': 109, 'Diastolic': 74, 'Rate': 76}, {'Systolic': 112, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 140, 'Diastolic': 89, 'Rate': 63}, {'Systolic': 134, 'Diastolic': 96, 'Rate': 98}, {'Systolic': 132, 'Diastolic': 74, 'Rate': 86}]}
# {'_id': 24, 'office_num': [5], 'patient_info': {'fname': 'Richard', 'lname': 'Boone'}, 'patient_numbers': ['447-375-9735', '292-978-2085', '823-597-7512', '243-180-9213'], 'weights': [192, 347, 380, 247, 306], 'height': 141, 'bp_readings': [{'Systolic': 149, 'Diastolic': 70, 'Rate': 79}, {'Systolic': 139, 'Diastolic': 77, 'Rate': 65}]}
# {'_id': 25, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Madden'}, 'patient_numbers': ['986-015-5214', '290-511-1453', '480-501-2653'], 'weights': [258], 'height': 135, 'bp_readings': [{'Systolic': 132, 'Diastolic': 98, 'Rate': 80}, {'Systolic': 107, 'Diastolic': 81, 'Rate': 110}]}
# {'_id': 26, 'office_num': [3], 'patient_info': {'fname': 'Jordan', 'lname': ' Fox'}, 'patient_numbers': ['199-879-6864', '348-209-8123', '364-804-8484'], 'weights': [154, 296, 143, 281], 'height': 108, 'bp_readings': [{'Systolic': 123, 'Diastolic': 87, 'Rate': 95}, {'Systolic': 146, 'Diastolic': 86, 'Rate': 103}, {'Systolic': 137, 'Diastolic': 70, 'Rate': 99}, {'Systolic': 119, 'Diastolic': 84, 'Rate': 103}, {'Systolic': 108, 'Diastolic': 74, 'Rate': 64}, {'Systolic': 137, 'Diastolic': 74, 'Rate': 103}, {'Systolic': 113, 'Diastolic': 85, 'Rate': 109}, {'Systolic': 121, 'Diastolic': 81, 'Rate': 78}, {'Systolic': 110, 'Diastolic': 74, 'Rate': 110}, {'Systolic': 124, 'Diastolic': 96, 'Rate': 88}]}
# {'_id': 27, 'office_num': [7], 'patient_info': {'fname': 'Betty', 'lname': 'Langston'}, 'patient_numbers': ['449-080-2681', '706-964-5669'], 'weights': [117, 140, 331, 109], 'height': 182, 'bp_readings': [{'Systolic': 102, 'Diastolic': 96, 'Rate': 67}, {'Systolic': 137, 'Diastolic': 74, 'Rate': 93}]}
# {'_id': 28, 'office_num': [9], 'patient_info': {'fname': 'Tom', 'lname': 'Madden'}, 'patient_numbers': ['495-739-3185', '210-565-4096', '665-457-3982', '051-828-7519'], 'weights': [335], 'height': 126, 'bp_readings': [{'Systolic': 140, 'Diastolic': 96, 'Rate': 71}, {'Systolic': 125, 'Diastolic': 92, 'Rate': 74}, {'Systolic': 106, 'Diastolic': 77, 'Rate': 81}, {'Systolic': 121, 'Diastolic': 91, 'Rate': 75}, {'Systolic': 150, 'Diastolic': 91, 'Rate': 89}, {'Systolic': 147, 'Diastolic': 85, 'Rate': 83}, {'Systolic': 131, 'Diastolic': 90, 'Rate': 109}, {'Systolic': 142, 'Diastolic': 93, 'Rate': 72}]}
# {'_id': 29, 'office_num': [7], 'patient_info': {'fname': 'Jack', 'lname': 'Hart'}, 'patient_numbers': ['197-422-0661', '012-768-4228', '140-763-8608', '362-253-1882'], 'weights': [282, 389], 'height': 102, 'bp_readings': [{'Systolic': 113, 'Diastolic': 83, 'Rate': 75}, {'Systolic': 150, 'Diastolic': 71, 'Rate': 93}, {'Systolic': 146, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 132, 'Diastolic': 92, 'Rate': 99}, {'Systolic': 141, 'Diastolic': 87, 'Rate': 64}, {'Systolic': 115, 'Diastolic': 82, 'Rate': 109}, {'Systolic': 129, 'Diastolic': 73, 'Rate': 96}, {'Systolic': 141, 'Diastolic': 71, 'Rate': 84}, {'Systolic': 105, 'Diastolic': 87, 'Rate': 66}, {'Systolic': 141, 'Diastolic': 96, 'Rate': 90}]}
# {'_id': 30, 'office_num': [1], 'patient_info': {'fname': 'Jerry', 'lname': 'Granger'}, 'patient_numbers': ['047-462-9285', '878-682-6637'], 'weights': [274, 167, 222], 'height': 172, 'bp_readings': [{'Systolic': 111, 'Diastolic': 94, 'Rate': 106}, {'Systolic': 139, 'Diastolic': 72, 'Rate': 106}, {'Systolic': 123, 'Diastolic': 80, 'Rate': 69}, {'Systolic': 116, 'Diastolic': 78, 'Rate': 76}, {'Systolic': 122, 'Diastolic': 82, 'Rate': 77}, {'Systolic': 136, 'Diastolic': 84, 'Rate': 60}]}
# {'_id': 31, 'office_num': [3], 'patient_info': {'fname': 'July', 'lname': ' Fox'}, 'patient_numbers': ['319-893-8639', '287-631-1200'], 'weights': [285, 303, 160, 392], 'height': 176, 'bp_readings': [{'Systolic': 143, 'Diastolic': 87, 'Rate': 94}, {'Systolic': 104, 'Diastolic': 99, 'Rate': 75}, {'Systolic': 124, 'Diastolic': 74, 'Rate': 78}, {'Systolic': 112, 'Diastolic': 91, 'Rate': 106}]}
# {'_id': 32, 'office_num': [7], 'patient_info': {'fname': 'Ethan', 'lname': 'Carmichael'}, 'patient_numbers': ['425-784-1843', '704-991-9574'], 'weights': [119, 116, 251, 171, 157], 'height': 180, 'bp_readings': [{'Systolic': 107, 'Diastolic': 97, 'Rate': 87}, {'Systolic': 140, 'Diastolic': 88, 'Rate': 75}, {'Systolic': 147, 'Diastolic': 76, 'Rate': 92}]}
# {'_id': 33, 'office_num': [9], 'patient_info': {'fname': 'Liam', 'lname': 'Smith'}, 'patient_numbers': ['368-294-0139', '678-934-0288', '364-664-7122', '807-073-6853'], 'weights': [129], 'height': 186, 'bp_readings': [{'Systolic': 127, 'Diastolic': 96, 'Rate': 88}, {'Systolic': 112, 'Diastolic': 75, 'Rate': 98}]}
# {'_id': 34, 'office_num': [9], 'patient_info': {'fname': 'James', 'lname': 'Hale'}, 'patient_numbers': ['853-359-1507', '092-247-0981', '961-689-4645'], 'weights': [115, 372, 334, 98], 'height': 154, 'bp_readings': [{'Systolic': 137, 'Diastolic': 93, 'Rate': 80}, {'Systolic': 150, 'Diastolic': 74, 'Rate': 98}, {'Systolic': 137, 'Diastolic': 87, 'Rate': 77}, {'Systolic': 104, 'Diastolic': 97, 'Rate': 98}, {'Systolic': 150, 'Diastolic': 95, 'Rate': 109}, {'Systolic': 123, 'Diastolic': 83, 'Rate': 85}]}
# {'_id': 35, 'office_num': [9], 'patient_info': {'fname': 'Tom', 'lname': 'Jones'}, 'patient_numbers': ['910-980-1555', '805-917-1875', '880-255-3292', '916-586-5549'], 'weights': [109, 122, 216], 'height': 133, 'bp_readings': [{'Systolic': 135, 'Diastolic': 79, 'Rate': 96}, {'Systolic': 150, 'Diastolic': 89, 'Rate': 65}, {'Systolic': 104, 'Diastolic': 92, 'Rate': 70}, {'Systolic': 117, 'Diastolic': 83, 'Rate': 65}, {'Systolic': 108, 'Diastolic': 79, 'Rate': 95}, {'Systolic': 146, 'Diastolic': 90, 'Rate': 76}, {'Systolic': 115, 'Diastolic': 76, 'Rate': 66}, {'Systolic': 117, 'Diastolic': 93, 'Rate': 90}]}
# {'_id': 36, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Hale'}, 'patient_numbers': ['381-855-4820', '750-056-2809', '862-331-9298'], 'weights': [226], 'height': 158, 'bp_readings': [{'Systolic': 150, 'Diastolic': 71, 'Rate': 83}, {'Systolic': 129, 'Diastolic': 80, 'Rate': 99}, {'Systolic': 146, 'Diastolic': 81, 'Rate': 74}, {'Systolic': 140, 'Diastolic': 70, 'Rate': 60}, {'Systolic': 131, 'Diastolic': 71, 'Rate': 70}]}
# {'_id': 37, 'office_num': [5], 'patient_info': {'fname': 'Jerry', 'lname': 'Jones'}, 'patient_numbers': ['318-208-3374', '378-556-1392'], 'weights': [242, 387], 'height': 154, 'bp_readings': [{'Systolic': 123, 'Diastolic': 70, 'Rate': 91}, {'Systolic': 101, 'Diastolic': 99, 'Rate': 66}, {'Systolic': 142, 'Diastolic': 90, 'Rate': 96}, {'Systolic': 142, 'Diastolic': 89, 'Rate': 87}, {'Systolic': 145, 'Diastolic': 88, 'Rate': 81}, {'Systolic': 121, 'Diastolic': 72, 'Rate': 101}, {'Systolic': 126, 'Diastolic': 76, 'Rate': 104}, {'Systolic': 132, 'Diastolic': 95, 'Rate': 91}, {'Systolic': 138, 'Diastolic': 88, 'Rate': 102}]}
# {'_id': 38, 'office_num': [9], 'patient_info': {'fname': 'Jerry', 'lname': 'Boone'}, 'patient_numbers': ['979-724-8496', '984-440-9077', '538-737-5266', '015-048-0460'], 'weights': [263, 248, 391], 'height': 200, 'bp_readings': [{'Systolic': 113, 'Diastolic': 92, 'Rate': 65}, {'Systolic': 121, 'Diastolic': 73, 'Rate': 102}]}
# {'_id': 39, 'office_num': [2], 'patient_info': {'fname': 'July', 'lname': ' Fox'}, 'patient_numbers': ['953-028-9544', '668-713-6390', '933-366-3924'], 'weights': [90, 247, 317], 'height': 163, 'bp_readings': [{'Systolic': 143, 'Diastolic': 74, 'Rate': 61}, {'Systolic': 123, 'Diastolic': 83, 'Rate': 95}, {'Systolic': 121, 'Diastolic': 97, 'Rate': 92}, {'Systolic': 131, 'Diastolic': 80, 'Rate': 98}]}
# {'_id': 40, 'office_num': [2], 'patient_info': {'fname': 'Jordan', 'lname': ' Fox'}, 'patient_numbers': ['460-417-1839', '465-301-9888', '224-013-0060', '100-085-5090'], 'weights': [198, 330, 192, 226, 241], 'height': 174, 'bp_readings': [{'Systolic': 133, 'Diastolic': 78, 'Rate': 74}, {'Systolic': 111, 'Diastolic': 76, 'Rate': 85}, {'Systolic': 103, 'Diastolic': 77, 'Rate': 95}, {'Systolic': 144, 'Diastolic': 84, 'Rate': 62}, {'Systolic': 121, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 107, 'Diastolic': 70, 'Rate': 96}, {'Systolic': 111, 'Diastolic': 86, 'Rate': 100}, {'Systolic': 105, 'Diastolic': 94, 'Rate': 71}, {'Systolic': 113, 'Diastolic': 77, 'Rate': 71}, {'Systolic': 119, 'Diastolic': 98, 'Rate': 66}]}
# {'_id': 41, 'office_num': [1], 'patient_info': {'fname': 'Tom', 'lname': 'Madden'}, 'patient_numbers': ['217-230-4509', '173-321-0301', '134-486-3043', '555-796-6163'], 'weights': [265, 181, 399, 148], 'height': 130, 'bp_readings': [{'Systolic': 149, 'Diastolic': 95, 'Rate': 87}, {'Systolic': 117, 'Diastolic': 87, 'Rate': 79}, {'Systolic': 121, 'Diastolic': 94, 'Rate': 83}]}
# {'_id': 42, 'office_num': [7], 'patient_info': {'fname': 'Jack', 'lname': 'Madden'}, 'patient_numbers': ['567-805-2424', '928-227-2221', '943-552-4741'], 'weights': [168, 371, 270, 320], 'height': 113, 'bp_readings': [{'Systolic': 143, 'Diastolic': 80, 'Rate': 64}, {'Systolic': 143, 'Diastolic': 75, 'Rate': 90}, {'Systolic': 134, 'Diastolic': 71, 'Rate': 62}, {'Systolic': 146, 'Diastolic': 76, 'Rate': 101}]}
# {'_id': 43, 'office_num': [6], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Madden'}, 'patient_numbers': ['585-512-6049', '303-459-6350', '349-031-2358', '422-314-9888'], 'weights': [367, 311, 314, 387, 352], 'height': 160, 'bp_readings': [{'Systolic': 132, 'Diastolic': 97, 'Rate': 82}, {'Systolic': 112, 'Diastolic': 83, 'Rate': 64}, {'Systolic': 117, 'Diastolic': 76, 'Rate': 74}, {'Systolic': 148, 'Diastolic': 74, 'Rate': 68}]}
# {'_id': 44, 'office_num': [4], 'patient_info': {'fname': 'John', 'lname': 'Carmichael'}, 'patient_numbers': ['520-519-3317', '395-290-3578', '005-785-2718'], 'weights': [380, 249, 399], 'height': 140, 'bp_readings': [{'Systolic': 130, 'Diastolic': 80, 'Rate': 86}, {'Systolic': 104, 'Diastolic': 78, 'Rate': 64}, {'Systolic': 142, 'Diastolic': 90, 'Rate': 80}]}
# {'_id': 45, 'office_num': [1], 'patient_info': {'fname': 'July', 'lname': 'Madden'}, 'patient_numbers': ['544-476-0424', '016-693-4597'], 'weights': [234, 221, 178, 255, 163], 'height': 145, 'bp_readings': [{'Systolic': 125, 'Diastolic': 81, 'Rate': 93}, {'Systolic': 147, 'Diastolic': 88, 'Rate': 104}, {'Systolic': 112, 'Diastolic': 82, 'Rate': 88}]}
# {'_id': 46, 'office_num': [3], 'patient_info': {'fname': 'Jack', 'lname': 'Granger'}, 'patient_numbers': ['311-088-7975', '829-760-6887'], 'weights': [393, 391], 'height': 147, 'bp_readings': [{'Systolic': 146, 'Diastolic': 81, 'Rate': 82}, {'Systolic': 128, 'Diastolic': 77, 'Rate': 104}]}
# {'_id': 47, 'office_num': [9], 'patient_info': {'fname': 'Richard', 'lname': 'Smith'}, 'patient_numbers': ['532-270-5952', '977-093-9072', '836-715-4225'], 'weights': [182, 361], 'height': 139, 'bp_readings': [{'Systolic': 135, 'Diastolic': 92, 'Rate': 87}, {'Systolic': 129, 'Diastolic': 84, 'Rate': 92}, {'Systolic': 135, 'Diastolic': 79, 'Rate': 70}, {'Systolic': 133, 'Diastolic': 89, 'Rate': 92}, {'Systolic': 119, 'Diastolic': 88, 'Rate': 110}]}
# {'_id': 48, 'office_num': [4], 'patient_info': {'fname': 'Richard', 'lname': 'Carmichael'}, 'patient_numbers': ['051-668-2977', '875-301-1186', '276-277-8909', '397-764-5294'], 'weights': [104, 374], 'height': 107, 'bp_readings': [{'Systolic': 135, 'Diastolic': 77, 'Rate': 88}, {'Systolic': 120, 'Diastolic': 84, 'Rate': 81}, {'Systolic': 147, 'Diastolic': 73, 'Rate': 84}]}
# {'_id': 49, 'office_num': [1], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Boone'}, 'patient_numbers': ['675-812-6869', '782-525-2933', '372-116-0725'], 'weights': [254, 233, 293, 97, 288], 'height': 162, 'bp_readings': [{'Systolic': 119, 'Diastolic': 93, 'Rate': 105}, {'Systolic': 119, 'Diastolic': 90, 'Rate': 97}, {'Systolic': 124, 'Diastolic': 80, 'Rate': 108}, {'Systolic': 118, 'Diastolic': 75, 'Rate': 66}, {'Systolic': 131, 'Diastolic': 75, 'Rate': 88}, {'Systolic': 109, 'Diastolic': 84, 'Rate': 66}, {'Systolic': 134, 'Diastolic': 73, 'Rate': 94}, {'Systolic': 120, 'Diastolic': 80, 'Rate': 91}, {'Systolic': 143, 'Diastolic': 87, 'Rate': 100}]}
# {'_id': 50, 'office_num': [6], 'patient_info': {'fname': 'Elizabeth', 'lname': 'Langston'}, 'patient_numbers': ['897-576-8323', '839-305-9056', '055-599-6343'], 'weights': [293, 286, 179], 'height': 101, 'bp_readings': [{'Systolic': 141, 'Diastolic': 98, 'Rate': 82}, {'Systolic': 138, 'Diastolic': 95, 'Rate': 109}, {'Systolic': 139, 'Diastolic': 96, 'Rate': 74}, {'Systolic': 114, 'Diastolic': 72, 'Rate': 99}, {'Systolic': 120, 'Diastolic': 82, 'Rate': 73}, {'Systolic': 145, 'Diastolic': 97, 'Rate': 78}, {'Systolic': 106, 'Diastolic': 83, 'Rate': 60}, {'Systolic': 122, 'Diastolic': 72, 'Rate': 86}]}

# %% [markdown]
# ### Find a document based on a (first level) field value

# %%
query = { "_id": 1 } # search for any five start restaurants
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4)) # using json.dumps() to make the output more readable
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": "good patient" }
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "comments": {"$regex": "ood" }} # https://en.wikipedia.org/wiki/Regular_expression
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Query values in an embedded array
# In our sample data, we have an embedded array of phone numbers. Here's how we can search an embedded array.

# %%
query = { "patient_numbers": {"$regex": '^177'}} # search for records that have this area code
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %%
query = { "bp_readings": {"Systolic" : 148 , "Diastolic": 84, "Rate": 78}} # in this style, you need all fields
doc = collection.find(query)
for record in doc:
  print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }

# %% [markdown]
# ### Querying embedded documents
#
# In our sample data, the readings field contains an array of embeded documents. Let's explore some examples showing how we can search an embedded document.

# %%
# in this style, you need all fields - so this one won't return anything
query = { "bp_readings": {"Systolic" : 148}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))

# %%
# If you want to query on one field, you can use the following approach
query = { "bp_readings.Systolic" : 148} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 43,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "585-512-6049",
#         "303-459-6350",
#         "349-031-2358",
#         "422-314-9888"
#     ],
#     "weights": [
#         367,
#         311,
#         314,
#         387,
#         352
#     ],
#     "height": 160,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 97,
#             "Rate": 82
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 64
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 76,
#             "Rate": 74
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 74,
#             "Rate": 68
#         }
#     ]
# }

# %%
# we can also check for greater than, greater than equal, less than, less than equal
query = { "bp_readings.Systolic" : {"$gte" : 130}} # in this style, you need all fields - so this one won't return anything
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 1,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": "Smith",
#         "mname": "Jane"
#     },
#     "patient_numbers": [
#         "177-763-1706",
#         "690-743-9150",
#         "008-063-6083"
#     ],
#     "weights": [
#         343,
#         373,
#         209,
#         266
#     ],
#     "height": 129,
#     "bp_readings": [
#         {
#             "Systolic": 148,
#             "Diastolic": 84,
#             "Rate": 78
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 73,
#             "Rate": 71
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 93,
#             "Rate": 78
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 93,
#             "Rate": 81
#         }
#     ],
#     "comments": "good patient",
#     "readings": [
#         {
#             "Systolic": 999,
#             "Diastolic": 999,
#             "Rate": 999
#         }
#     ]
# }
# {
#     "_id": 2,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "344-978-6907",
#         "366-258-5178",
#         "128-657-0704",
#         "999-622-8303"
#     ],
#     "weights": [
#         370,
#         208,
#         297,
#         353,
#         266
#     ],
#     "height": 173,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 99,
#             "Rate": 77
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 87,
#             "Rate": 98
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 70,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 97,
#             "Rate": 107
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 95,
#             "Rate": 68
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 94,
#             "Rate": 95
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 83,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 3,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "386-756-5088",
#         "995-790-3289",
#         "218-401-1070",
#         "434-192-5412"
#     ],
#     "weights": [
#         220,
#         360
#     ],
#     "height": 121,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 92,
#             "Rate": 78
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 92,
#             "Rate": 80
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 85,
#             "Rate": 67
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 79,
#             "Rate": 84
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 83,
#             "Rate": 110
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 78,
#             "Rate": 66
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "101-222-8345",
#         "984-555-1439"
#     ],
#     "weights": [
#         159,
#         386,
#         372,
#         143
#     ],
#     "height": 141,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 72,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "619-839-1454",
#         "981-741-0409",
#         "016-103-3962",
#         "172-321-6684"
#     ],
#     "weights": [
#         219,
#         334,
#         251,
#         141,
#         196
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 70,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 99,
#             "Rate": 78
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 89,
#             "Rate": 80
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 82,
#             "Rate": 80
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 72,
#             "Rate": 64
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 89,
#             "Rate": 89
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 78,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 9,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "182-222-5418",
#         "942-328-0598",
#         "324-682-0341"
#     ],
#     "weights": [
#         310,
#         371,
#         218,
#         367
#     ],
#     "height": 156,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 70,
#             "Rate": 85
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 75,
#             "Rate": 76
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 70,
#             "Rate": 110
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 99,
#             "Rate": 86
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 70,
#             "Rate": 63
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 81,
#             "Rate": 97
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 88,
#             "Rate": 68
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 78,
#             "Rate": 77
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 88,
#             "Rate": 85
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 89,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 10,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "858-733-5773",
#         "658-943-0185"
#     ],
#     "weights": [
#         351,
#         194
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 144,
#             "Diastolic": 79,
#             "Rate": 95
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 75,
#             "Rate": 104
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 93,
#             "Rate": 89
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 72,
#             "Rate": 67
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 86,
#             "Rate": 96
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 75,
#             "Rate": 69
#         }
#     ]
# }
# {
#     "_id": 11,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "076-568-2808",
#         "141-412-9173",
#         "666-257-2973",
#         "169-861-4436"
#     ],
#     "weights": [
#         92,
#         187,
#         360,
#         314,
#         386
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 89,
#             "Rate": 75
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 76,
#             "Rate": 71
#         }
#     ]
# }
# {
#     "_id": 12,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "449-472-8576",
#         "139-634-1019"
#     ],
#     "weights": [
#         369
#     ],
#     "height": 137,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 86,
#             "Rate": 83
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 95,
#             "Rate": 79
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 86,
#             "Rate": 103
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 94,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 13,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "754-865-9716",
#         "638-049-8379",
#         "864-279-8358"
#     ],
#     "weights": [
#         289
#     ],
#     "height": 174,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 80,
#             "Rate": 99
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 104
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 72,
#             "Rate": 91
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 77,
#             "Rate": 100
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 79,
#             "Rate": 100
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 83,
#             "Rate": 106
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 74,
#             "Rate": 100
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 99,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 14,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "054-684-2747",
#         "278-048-1961",
#         "517-028-2164",
#         "943-833-5411"
#     ],
#     "weights": [
#         278,
#         329,
#         351,
#         375,
#         115
#     ],
#     "height": 121,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 93,
#             "Rate": 105
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 78,
#             "Rate": 82
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 93,
#             "Rate": 74
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 87,
#             "Rate": 85
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 85,
#             "Rate": 110
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 97,
#             "Rate": 99
#         }
#     ]
# }
# {
#     "_id": 15,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "930-965-6343",
#         "129-792-9478",
#         "222-754-6313"
#     ],
#     "weights": [
#         124,
#         144,
#         206
#     ],
#     "height": 150,
#     "bp_readings": [
#         {
#             "Systolic": 131,
#             "Diastolic": 99,
#             "Rate": 66
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 71,
#             "Rate": 63
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 70,
#             "Rate": 108
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 91,
#             "Rate": 62
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 92,
#             "Rate": 93
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 98,
#             "Rate": 99
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 80,
#             "Rate": 102
#         }
#     ]
# }
# {
#     "_id": 16,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "213-637-7623",
#         "347-896-3745",
#         "791-310-0075",
#         "694-362-2006"
#     ],
#     "weights": [
#         367,
#         119
#     ],
#     "height": 172,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 74,
#             "Rate": 65
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 90,
#             "Rate": 79
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 71,
#             "Rate": 94
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 86,
#             "Rate": 68
#         },
#         {
#             "Systolic": 102,
#             "Diastolic": 99,
#             "Rate": 77
#         },
#         {
#             "Systolic": 149,
#             "Diastolic": 73,
#             "Rate": 87
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 76,
#             "Rate": 61
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 90,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 18,
#     "office_num": [
#         8
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "145-140-6045",
#         "246-141-6388",
#         "355-869-7127"
#     ],
#     "weights": [
#         376,
#         387,
#         356,
#         364,
#         105
#     ],
#     "height": 137,
#     "bp_readings": [
#         {
#             "Systolic": 112,
#             "Diastolic": 81,
#             "Rate": 84
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 80,
#             "Rate": 66
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 81,
#             "Rate": 68
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 72,
#             "Rate": 62
#         }
#     ]
# }
# {
#     "_id": 19,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "645-545-8808",
#         "125-559-1747",
#         "756-190-2087"
#     ],
#     "weights": [
#         218,
#         215,
#         383,
#         263,
#         275
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 79,
#             "Rate": 89
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 80,
#             "Rate": 94
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 75,
#             "Rate": 61
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 78,
#             "Rate": 103
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 88,
#             "Rate": 68
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 75,
#             "Rate": 109
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 93,
#             "Rate": 99
#         }
#     ]
# }
# {
#     "_id": 20,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "413-419-8113",
#         "286-095-7433",
#         "973-675-8371",
#         "463-086-8716"
#     ],
#     "weights": [
#         351,
#         386,
#         389,
#         307,
#         110
#     ],
#     "height": 145,
#     "bp_readings": [
#         {
#             "Systolic": 100,
#             "Diastolic": 76,
#             "Rate": 79
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 92,
#             "Rate": 101
#         },
#         {
#             "Systolic": 100,
#             "Diastolic": 87,
#             "Rate": 67
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 86,
#             "Rate": 107
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 94,
#             "Rate": 94
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 88,
#             "Rate": 95
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 86,
#             "Rate": 86
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 96,
#             "Rate": 93
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 89,
#             "Rate": 100
#         }
#     ]
# }
# {
#     "_id": 21,
#     "office_num": [
#         10
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "287-928-2406",
#         "905-664-0110",
#         "647-457-5671"
#     ],
#     "weights": [
#         271,
#         164,
#         302,
#         165
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 116,
#             "Diastolic": 81,
#             "Rate": 68
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 95,
#             "Rate": 78
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 78,
#             "Rate": 92
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 93,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 22,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "376-611-2323",
#         "014-271-6201",
#         "690-838-6501"
#     ],
#     "weights": [
#         304,
#         150,
#         225,
#         232,
#         181
#     ],
#     "height": 161,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 76,
#             "Rate": 103
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 72,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 23,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Susan",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "876-197-1269",
#         "328-468-4783",
#         "957-105-4087"
#     ],
#     "weights": [
#         141,
#         207,
#         350
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 145,
#             "Diastolic": 77,
#             "Rate": 86
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 74,
#             "Rate": 76
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 89,
#             "Rate": 63
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 96,
#             "Rate": 98
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 74,
#             "Rate": 86
#         }
#     ]
# }
# {
#     "_id": 24,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "447-375-9735",
#         "292-978-2085",
#         "823-597-7512",
#         "243-180-9213"
#     ],
#     "weights": [
#         192,
#         347,
#         380,
#         247,
#         306
#     ],
#     "height": 141,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 70,
#             "Rate": 79
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 77,
#             "Rate": 65
#         }
#     ]
# }
# {
#     "_id": 25,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "986-015-5214",
#         "290-511-1453",
#         "480-501-2653"
#     ],
#     "weights": [
#         258
#     ],
#     "height": 135,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 98,
#             "Rate": 80
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 81,
#             "Rate": 110
#         }
#     ]
# }
# {
#     "_id": 26,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "199-879-6864",
#         "348-209-8123",
#         "364-804-8484"
#     ],
#     "weights": [
#         154,
#         296,
#         143,
#         281
#     ],
#     "height": 108,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 87,
#             "Rate": 95
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 86,
#             "Rate": 103
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 70,
#             "Rate": 99
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 84,
#             "Rate": 103
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 74,
#             "Rate": 64
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 74,
#             "Rate": 103
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 85,
#             "Rate": 109
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 81,
#             "Rate": 78
#         },
#         {
#             "Systolic": 110,
#             "Diastolic": 74,
#             "Rate": 110
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 96,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 27,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "449-080-2681",
#         "706-964-5669"
#     ],
#     "weights": [
#         117,
#         140,
#         331,
#         109
#     ],
#     "height": 182,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 96,
#             "Rate": 67
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 74,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "495-739-3185",
#         "210-565-4096",
#         "665-457-3982",
#         "051-828-7519"
#     ],
#     "weights": [
#         335
#     ],
#     "height": 126,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 96,
#             "Rate": 71
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 92,
#             "Rate": 74
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 77,
#             "Rate": 81
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 91,
#             "Rate": 75
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 89
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 85,
#             "Rate": 83
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 90,
#             "Rate": 109
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 72
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "197-422-0661",
#         "012-768-4228",
#         "140-763-8608",
#         "362-253-1882"
#     ],
#     "weights": [
#         282,
#         389
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 113,
#             "Diastolic": 83,
#             "Rate": 75
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 93
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 92,
#             "Rate": 99
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 87,
#             "Rate": 64
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 109
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 73,
#             "Rate": 96
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 71,
#             "Rate": 84
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 87,
#             "Rate": 66
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 96,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 30,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "047-462-9285",
#         "878-682-6637"
#     ],
#     "weights": [
#         274,
#         167,
#         222
#     ],
#     "height": 172,
#     "bp_readings": [
#         {
#             "Systolic": 111,
#             "Diastolic": 94,
#             "Rate": 106
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 72,
#             "Rate": 106
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 80,
#             "Rate": 69
#         },
#         {
#             "Systolic": 116,
#             "Diastolic": 78,
#             "Rate": 76
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 82,
#             "Rate": 77
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 84,
#             "Rate": 60
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "319-893-8639",
#         "287-631-1200"
#     ],
#     "weights": [
#         285,
#         303,
#         160,
#         392
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 87,
#             "Rate": 94
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 99,
#             "Rate": 75
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 74,
#             "Rate": 78
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 91,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 32,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Ethan",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "425-784-1843",
#         "704-991-9574"
#     ],
#     "weights": [
#         119,
#         116,
#         251,
#         171,
#         157
#     ],
#     "height": 180,
#     "bp_readings": [
#         {
#             "Systolic": 107,
#             "Diastolic": 97,
#             "Rate": 87
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 88,
#             "Rate": 75
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 76,
#             "Rate": 92
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "853-359-1507",
#         "092-247-0981",
#         "961-689-4645"
#     ],
#     "weights": [
#         115,
#         372,
#         334,
#         98
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 80
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 98
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 87,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 98
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 95,
#             "Rate": 109
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 83,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "910-980-1555",
#         "805-917-1875",
#         "880-255-3292",
#         "916-586-5549"
#     ],
#     "weights": [
#         109,
#         122,
#         216
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 79,
#             "Rate": 96
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 89,
#             "Rate": 65
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 83,
#             "Rate": 65
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 79,
#             "Rate": 95
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 90,
#             "Rate": 76
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 76,
#             "Rate": 66
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "381-855-4820",
#         "750-056-2809",
#         "862-331-9298"
#     ],
#     "weights": [
#         226
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 80,
#             "Rate": 99
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 70,
#             "Rate": 60
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 70
#         }
#     ]
# }
# {
#     "_id": 37,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Jerry",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "318-208-3374",
#         "378-556-1392"
#     ],
#     "weights": [
#         242,
#         387
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 123,
#             "Diastolic": 70,
#             "Rate": 91
#         },
#         {
#             "Systolic": 101,
#             "Diastolic": 99,
#             "Rate": 66
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 96
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 89,
#             "Rate": 87
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 88,
#             "Rate": 81
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 72,
#             "Rate": 101
#         },
#         {
#             "Systolic": 126,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 95,
#             "Rate": 91
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 88,
#             "Rate": 102
#         }
#     ]
# }
# {
#     "_id": 39,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "953-028-9544",
#         "668-713-6390",
#         "933-366-3924"
#     ],
#     "weights": [
#         90,
#         247,
#         317
#     ],
#     "height": 163,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 74,
#             "Rate": 61
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 83,
#             "Rate": 95
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 97,
#             "Rate": 92
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 80,
#             "Rate": 98
#         }
#     ]
# }
# {
#     "_id": 40,
#     "office_num": [
#         2
#     ],
#     "patient_info": {
#         "fname": "Jordan",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "460-417-1839",
#         "465-301-9888",
#         "224-013-0060",
#         "100-085-5090"
#     ],
#     "weights": [
#         198,
#         330,
#         192,
#         226,
#         241
#     ],
#     "height": 174,
#     "bp_readings": [
#         {
#             "Systolic": 133,
#             "Diastolic": 78,
#             "Rate": 74
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 76,
#             "Rate": 85
#         },
#         {
#             "Systolic": 103,
#             "Diastolic": 77,
#             "Rate": 95
#         },
#         {
#             "Systolic": 144,
#             "Diastolic": 84,
#             "Rate": 62
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 80,
#             "Rate": 86
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 70,
#             "Rate": 96
#         },
#         {
#             "Systolic": 111,
#             "Diastolic": 86,
#             "Rate": 100
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 94,
#             "Rate": 71
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 77,
#             "Rate": 71
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 98,
#             "Rate": 66
#         }
#     ]
# }
# {
#     "_id": 41,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "217-230-4509",
#         "173-321-0301",
#         "134-486-3043",
#         "555-796-6163"
#     ],
#     "weights": [
#         265,
#         181,
#         399,
#         148
#     ],
#     "height": 130,
#     "bp_readings": [
#         {
#             "Systolic": 149,
#             "Diastolic": 95,
#             "Rate": 87
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 87,
#             "Rate": 79
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 94,
#             "Rate": 83
#         }
#     ]
# }
# {
#     "_id": 42,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "567-805-2424",
#         "928-227-2221",
#         "943-552-4741"
#     ],
#     "weights": [
#         168,
#         371,
#         270,
#         320
#     ],
#     "height": 113,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 80,
#             "Rate": 64
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 75,
#             "Rate": 90
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 71,
#             "Rate": 62
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 76,
#             "Rate": 101
#         }
#     ]
# }
# {
#     "_id": 43,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "585-512-6049",
#         "303-459-6350",
#         "349-031-2358",
#         "422-314-9888"
#     ],
#     "weights": [
#         367,
#         311,
#         314,
#         387,
#         352
#     ],
#     "height": 160,
#     "bp_readings": [
#         {
#             "Systolic": 132,
#             "Diastolic": 97,
#             "Rate": 82
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 83,
#             "Rate": 64
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 76,
#             "Rate": 74
#         },
#         {
#             "Systolic": 148,
#             "Diastolic": 74,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "520-519-3317",
#         "395-290-3578",
#         "005-785-2718"
#     ],
#     "weights": [
#         380,
#         249,
#         399
#     ],
#     "height": 140,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 86
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 78,
#             "Rate": 64
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 80
#         }
#     ]
# }
# {
#     "_id": 45,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "544-476-0424",
#         "016-693-4597"
#     ],
#     "weights": [
#         234,
#         221,
#         178,
#         255,
#         163
#     ],
#     "height": 145,
#     "bp_readings": [
#         {
#             "Systolic": 125,
#             "Diastolic": 81,
#             "Rate": 93
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 88,
#             "Rate": 104
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 82,
#             "Rate": 88
#         }
#     ]
# }
# {
#     "_id": 46,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Granger"
#     },
#     "patient_numbers": [
#         "311-088-7975",
#         "829-760-6887"
#     ],
#     "weights": [
#         393,
#         391
#     ],
#     "height": 147,
#     "bp_readings": [
#         {
#             "Systolic": 146,
#             "Diastolic": 81,
#             "Rate": 82
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 77,
#             "Rate": 104
#         }
#     ]
# }
# {
#     "_id": 47,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Smith"
#     },
#     "patient_numbers": [
#         "532-270-5952",
#         "977-093-9072",
#         "836-715-4225"
#     ],
#     "weights": [
#         182,
#         361
#     ],
#     "height": 139,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 92,
#             "Rate": 87
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 84,
#             "Rate": 92
#         },
#         {
#             "Systolic": 135,
#             "Diastolic": 79,
#             "Rate": 70
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 89,
#             "Rate": 92
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 88,
#             "Rate": 110
#         }
#     ]
# }
# {
#     "_id": 48,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "Richard",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "051-668-2977",
#         "875-301-1186",
#         "276-277-8909",
#         "397-764-5294"
#     ],
#     "weights": [
#         104,
#         374
#     ],
#     "height": 107,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 77,
#             "Rate": 88
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 84,
#             "Rate": 81
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 73,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 49,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Boone"
#     },
#     "patient_numbers": [
#         "675-812-6869",
#         "782-525-2933",
#         "372-116-0725"
#     ],
#     "weights": [
#         254,
#         233,
#         293,
#         97,
#         288
#     ],
#     "height": 162,
#     "bp_readings": [
#         {
#             "Systolic": 119,
#             "Diastolic": 93,
#             "Rate": 105
#         },
#         {
#             "Systolic": 119,
#             "Diastolic": 90,
#             "Rate": 97
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 80,
#             "Rate": 108
#         },
#         {
#             "Systolic": 118,
#             "Diastolic": 75,
#             "Rate": 66
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 75,
#             "Rate": 88
#         },
#         {
#             "Systolic": 109,
#             "Diastolic": 84,
#             "Rate": 66
#         },
#         {
#             "Systolic": 134,
#             "Diastolic": 73,
#             "Rate": 94
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 80,
#             "Rate": 91
#         },
#         {
#             "Systolic": 143,
#             "Diastolic": 87,
#             "Rate": 100
#         }
#     ]
# }
# {
#     "_id": 50,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "897-576-8323",
#         "839-305-9056",
#         "055-599-6343"
#     ],
#     "weights": [
#         293,
#         286,
#         179
#     ],
#     "height": 101,
#     "bp_readings": [
#         {
#             "Systolic": 141,
#             "Diastolic": 98,
#             "Rate": 82
#         },
#         {
#             "Systolic": 138,
#             "Diastolic": 95,
#             "Rate": 109
#         },
#         {
#             "Systolic": 139,
#             "Diastolic": 96,
#             "Rate": 74
#         },
#         {
#             "Systolic": 114,
#             "Diastolic": 72,
#             "Rate": 99
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 82,
#             "Rate": 73
#         },
#         {
#             "Systolic": 145,
#             "Diastolic": 97,
#             "Rate": 78
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 83,
#             "Rate": 60
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 72,
#             "Rate": 86
#         }
#     ]
# }

# %% [markdown]
# Another approach is to use \$elemMatch. This will conduct an element wise match of the fields in an array of embedded documents.

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : 104}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 12,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "449-472-8576",
#         "139-634-1019"
#     ],
#     "weights": [
#         369
#     ],
#     "height": 137,
#     "bp_readings": [
#         {
#             "Systolic": 104,
#             "Diastolic": 86,
#             "Rate": 83
#         },
#         {
#             "Systolic": 136,
#             "Diastolic": 95,
#             "Rate": 79
#         },
#         {
#             "Systolic": 127,
#             "Diastolic": 86,
#             "Rate": 103
#         },
#         {
#             "Systolic": 122,
#             "Diastolic": 94,
#             "Rate": 93
#         }
#     ]
# }
# {
#     "_id": 31,
#     "office_num": [
#         3
#     ],
#     "patient_info": {
#         "fname": "July",
#         "lname": " Fox"
#     },
#     "patient_numbers": [
#         "319-893-8639",
#         "287-631-1200"
#     ],
#     "weights": [
#         285,
#         303,
#         160,
#         392
#     ],
#     "height": 176,
#     "bp_readings": [
#         {
#             "Systolic": 143,
#             "Diastolic": 87,
#             "Rate": 94
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 99,
#             "Rate": 75
#         },
#         {
#             "Systolic": 124,
#             "Diastolic": 74,
#             "Rate": 78
#         },
#         {
#             "Systolic": 112,
#             "Diastolic": 91,
#             "Rate": 106
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "853-359-1507",
#         "092-247-0981",
#         "961-689-4645"
#     ],
#     "weights": [
#         115,
#         372,
#         334,
#         98
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 80
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 98
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 87,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 98
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 95,
#             "Rate": 109
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 83,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "910-980-1555",
#         "805-917-1875",
#         "880-255-3292",
#         "916-586-5549"
#     ],
#     "weights": [
#         109,
#         122,
#         216
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 79,
#             "Rate": 96
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 89,
#             "Rate": 65
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 83,
#             "Rate": 65
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 79,
#             "Rate": 95
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 90,
#             "Rate": 76
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 76,
#             "Rate": 66
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 44,
#     "office_num": [
#         4
#     ],
#     "patient_info": {
#         "fname": "John",
#         "lname": "Carmichael"
#     },
#     "patient_numbers": [
#         "520-519-3317",
#         "395-290-3578",
#         "005-785-2718"
#     ],
#     "weights": [
#         380,
#         249,
#         399
#     ],
#     "height": 140,
#     "bp_readings": [
#         {
#             "Systolic": 130,
#             "Diastolic": 80,
#             "Rate": 86
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 78,
#             "Rate": 64
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 90,
#             "Rate": 80
#         }
#     ]
# }

# %%
query = { "bp_readings" : {"$elemMatch" : {'Systolic' : {'$gte': 150}}}} 
doc = collection.find(query)
for record in doc:
    print(json.dumps(record, indent=4))
# Out:
# {
#     "_id": 2,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "344-978-6907",
#         "366-258-5178",
#         "128-657-0704",
#         "999-622-8303"
#     ],
#     "weights": [
#         370,
#         208,
#         297,
#         353,
#         266
#     ],
#     "height": 173,
#     "bp_readings": [
#         {
#             "Systolic": 129,
#             "Diastolic": 99,
#             "Rate": 77
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 87,
#             "Rate": 98
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 70,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 97,
#             "Rate": 107
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 95,
#             "Rate": 68
#         },
#         {
#             "Systolic": 133,
#             "Diastolic": 94,
#             "Rate": 95
#         },
#         {
#             "Systolic": 113,
#             "Diastolic": 83,
#             "Rate": 63
#         }
#     ]
# }
# {
#     "_id": 6,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "101-222-8345",
#         "984-555-1439"
#     ],
#     "weights": [
#         159,
#         386,
#         372,
#         143
#     ],
#     "height": 141,
#     "bp_readings": [
#         {
#             "Systolic": 126,
#             "Diastolic": 72,
#             "Rate": 84
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 68
#         }
#     ]
# }
# {
#     "_id": 7,
#     "office_num": [
#         6
#     ],
#     "patient_info": {
#         "fname": "Betty",
#         "lname": "Langston"
#     },
#     "patient_numbers": [
#         "619-839-1454",
#         "981-741-0409",
#         "016-103-3962",
#         "172-321-6684"
#     ],
#     "weights": [
#         219,
#         334,
#         251,
#         141,
#         196
#     ],
#     "height": 183,
#     "bp_readings": [
#         {
#             "Systolic": 102,
#             "Diastolic": 70,
#             "Rate": 60
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 99,
#             "Rate": 78
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 89,
#             "Rate": 80
#         },
#         {
#             "Systolic": 128,
#             "Diastolic": 82,
#             "Rate": 80
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 72,
#             "Rate": 64
#         },
#         {
#             "Systolic": 120,
#             "Diastolic": 89,
#             "Rate": 89
#         },
#         {
#             "Systolic": 107,
#             "Diastolic": 78,
#             "Rate": 73
#         }
#     ]
# }
# {
#     "_id": 22,
#     "office_num": [
#         5
#     ],
#     "patient_info": {
#         "fname": "Liam",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "376-611-2323",
#         "014-271-6201",
#         "690-838-6501"
#     ],
#     "weights": [
#         304,
#         150,
#         225,
#         232,
#         181
#     ],
#     "height": 161,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 76,
#             "Rate": 103
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 72,
#             "Rate": 84
#         }
#     ]
# }
# {
#     "_id": 28,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Madden"
#     },
#     "patient_numbers": [
#         "495-739-3185",
#         "210-565-4096",
#         "665-457-3982",
#         "051-828-7519"
#     ],
#     "weights": [
#         335
#     ],
#     "height": 126,
#     "bp_readings": [
#         {
#             "Systolic": 140,
#             "Diastolic": 96,
#             "Rate": 71
#         },
#         {
#             "Systolic": 125,
#             "Diastolic": 92,
#             "Rate": 74
#         },
#         {
#             "Systolic": 106,
#             "Diastolic": 77,
#             "Rate": 81
#         },
#         {
#             "Systolic": 121,
#             "Diastolic": 91,
#             "Rate": 75
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 91,
#             "Rate": 89
#         },
#         {
#             "Systolic": 147,
#             "Diastolic": 85,
#             "Rate": 83
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 90,
#             "Rate": 109
#         },
#         {
#             "Systolic": 142,
#             "Diastolic": 93,
#             "Rate": 72
#         }
#     ]
# }
# {
#     "_id": 29,
#     "office_num": [
#         7
#     ],
#     "patient_info": {
#         "fname": "Jack",
#         "lname": "Hart"
#     },
#     "patient_numbers": [
#         "197-422-0661",
#         "012-768-4228",
#         "140-763-8608",
#         "362-253-1882"
#     ],
#     "weights": [
#         282,
#         389
#     ],
#     "height": 102,
#     "bp_readings": [
#         {
#             "Systolic": 113,
#             "Diastolic": 83,
#             "Rate": 75
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 93
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 76,
#             "Rate": 104
#         },
#         {
#             "Systolic": 132,
#             "Diastolic": 92,
#             "Rate": 99
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 87,
#             "Rate": 64
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 82,
#             "Rate": 109
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 73,
#             "Rate": 96
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 71,
#             "Rate": 84
#         },
#         {
#             "Systolic": 105,
#             "Diastolic": 87,
#             "Rate": 66
#         },
#         {
#             "Systolic": 141,
#             "Diastolic": 96,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 34,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "James",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "853-359-1507",
#         "092-247-0981",
#         "961-689-4645"
#     ],
#     "weights": [
#         115,
#         372,
#         334,
#         98
#     ],
#     "height": 154,
#     "bp_readings": [
#         {
#             "Systolic": 137,
#             "Diastolic": 93,
#             "Rate": 80
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 74,
#             "Rate": 98
#         },
#         {
#             "Systolic": 137,
#             "Diastolic": 87,
#             "Rate": 77
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 97,
#             "Rate": 98
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 95,
#             "Rate": 109
#         },
#         {
#             "Systolic": 123,
#             "Diastolic": 83,
#             "Rate": 85
#         }
#     ]
# }
# {
#     "_id": 35,
#     "office_num": [
#         9
#     ],
#     "patient_info": {
#         "fname": "Tom",
#         "lname": "Jones"
#     },
#     "patient_numbers": [
#         "910-980-1555",
#         "805-917-1875",
#         "880-255-3292",
#         "916-586-5549"
#     ],
#     "weights": [
#         109,
#         122,
#         216
#     ],
#     "height": 133,
#     "bp_readings": [
#         {
#             "Systolic": 135,
#             "Diastolic": 79,
#             "Rate": 96
#         },
#         {
#             "Systolic": 150,
#             "Diastolic": 89,
#             "Rate": 65
#         },
#         {
#             "Systolic": 104,
#             "Diastolic": 92,
#             "Rate": 70
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 83,
#             "Rate": 65
#         },
#         {
#             "Systolic": 108,
#             "Diastolic": 79,
#             "Rate": 95
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 90,
#             "Rate": 76
#         },
#         {
#             "Systolic": 115,
#             "Diastolic": 76,
#             "Rate": 66
#         },
#         {
#             "Systolic": 117,
#             "Diastolic": 93,
#             "Rate": 90
#         }
#     ]
# }
# {
#     "_id": 36,
#     "office_num": [
#         1
#     ],
#     "patient_info": {
#         "fname": "Elizabeth",
#         "lname": "Hale"
#     },
#     "patient_numbers": [
#         "381-855-4820",
#         "750-056-2809",
#         "862-331-9298"
#     ],
#     "weights": [
#         226
#     ],
#     "height": 158,
#     "bp_readings": [
#         {
#             "Systolic": 150,
#             "Diastolic": 71,
#             "Rate": 83
#         },
#         {
#             "Systolic": 129,
#             "Diastolic": 80,
#             "Rate": 99
#         },
#         {
#             "Systolic": 146,
#             "Diastolic": 81,
#             "Rate": 74
#         },
#         {
#             "Systolic": 140,
#             "Diastolic": 70,
#             "Rate": 60
#         },
#         {
#             "Systolic": 131,
#             "Diastolic": 71,
#             "Rate": 70
#         }
#     ]
# }

# %%
client.close()

# %% [markdown]
# ## Step 3: Review other possibly querries
#
# There are many ways we could use MongoDB to query the data. See here for more examples https://docs.mongodb.com/manual/tutorial/query-documents/. I'd also encourate you to experiment and try queries through the MongoDB online interface.

# %% [markdown]
# ## Use of Indices
#
# Indices can be used to improve the performance of queries. See [here](https://docs.mongodb.com/manual/indexes/) for more information on indices.
